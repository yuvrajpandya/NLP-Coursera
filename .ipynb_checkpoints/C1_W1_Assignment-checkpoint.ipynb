# %% [markdown]
# # Assignment 1: Logistic Regression
# Welcome to week one of this specialization. You will learn about logistic regression. Concretely, you will be implementing logistic regression for sentiment analysis on tweets. Given a tweet, you will decide if it has a positive sentiment or a negative one. Specifically you will:
#
# * Learn how to extract features for logistic regression given some text
# * Implement logistic regression from scratch
# * Apply logistic regression on a natural language processing task
# * Test using your logistic regression
# * Perform error analysis
#
# We will be using a data set of tweets. Hopefully you will get more than 99% accuracy.
# Run the cell below to load in the packages.

# %% [markdown]
# ## Import functions and data

# %%
# run this cell to import nltk
import nltk
from os import getcwd

# %% [markdown]
# ### Imported functions
#
# Download the data needed for this assignment. Check out the [documentation for the twitter_samples dataset](http://www.nltk.org/howto/twitter.html).
#
# * twitter_samples: if you're running this notebook on your local computer, you will need to download it using:
# ```Python
# nltk.download('twitter_samples')
# ```
#
# * stopwords: if you're running this notebook on your local computer, you will need to download it using:
# ```python
# nltk.download('stopwords')
# ```
#
# #### Import some helper functions that we provided in the utils.py file:
# * `process_tweet()`: cleans the text, tokenizes it into separate words, removes stopwords, and converts words to stems.
# * `build_freqs()`: this counts how often a word in the 'corpus' (the entire set of tweets) was associated with a positive label '1' or a negative label '0', then builds the `freqs` dictionary, where each key is a (word,label) tuple, and the value is the count of its frequency within the corpus of tweets.

# %%
# add folder, tmp2, from our local workspace containing pre-downloaded corpora files to nltk's data path
# this enables importing of these files without downloading it again when we refresh our workspace

filePath = f"{getcwd()}/../tmp2/"
nltk.data.path.append(filePath)

# %%
import numpy as np
import pandas as pd
import math
from nltk.corpus import twitter_samples 

from utils import process_tweet, build_freqs

# %% [markdown]
# ### Prepare the data
# * The `twitter_samples` contains subsets of 5,000 positive tweets, 5,000 negative tweets, and the full set of 10,000 tweets.
#     * If you used all three datasets, we would introduce duplicates of the positive tweets and negative tweets.
#     * You will select just the five thousand positive tweets and five thousand negative tweets.

# %%
# select the set of positive and negative tweets
all_positive_tweets = twitter_samples.strings('positive_tweets.json')
all_negative_tweets = twitter_samples.strings('negative_tweets.json')

# %% [markdown]
# * Train test split: 20% will be in the test set, and 80% in the training set.

# %%
# split the data into two pieces, one for training and one for testing (validation set) 
test_pos = all_positive_tweets[4000:]
train_pos = all_positive_tweets[:4000]
test_neg = all_negative_tweets[4000:]
train_neg = all_negative_tweets[:4000]

train_x = train_pos + train_neg 
test_x = test_pos + test_neg

# %% [markdown]
# * Create the numpy array of positive labels and negative labels.

# %%
# combine positive and negative labels
train_y = np.append(np.ones((len(train_pos), 1)), np.zeros((len(train_neg), 1)), axis=0)
test_y = np.append(np.ones((len(test_pos), 1)), np.zeros((len(test_neg), 1)), axis=0)

# %%
# Print the shape train and test sets
print("train_y.shape = " + str(train_y.shape))
print("test_y.shape = " + str(test_y.shape))
# Out:
# train_y.shape = (8000, 1)
# test_y.shape = (2000, 1)

# %% [markdown]
# * Create the frequency dictionary using the imported `build_freqs()` function.
#     * We highly recommend that you open `utils.py` and read the `build_freqs()` function to understand what it is doing.
#     * To view the file directory, go to the menu and click File->Open.
#
# ```Python
#     for y,tweet in zip(ys, tweets):
#         for word in process_tweet(tweet):
#             pair = (word, y)
#             if pair in freqs:
#                 freqs[pair] += 1
#             else:
#                 freqs[pair] = 1
# ```
# * Notice how the outer for loop goes through each tweet, and the inner for loop steps through each word in a tweet.
# * The `freqs` dictionary is the frequency dictionary that's being built.
# * The key is the tuple (word, label), such as ("happy",1) or ("happy",0).  The value stored for each key is the count of how many times the word "happy" was associated with a positive label, or how many times "happy" was associated with a negative label.

# %%
# create frequency dictionary
freqs = build_freqs(train_x, train_y)

# check the output
print("type(freqs) = " + str(type(freqs)))
print("len(freqs) = " + str(len(freqs.keys())))
# Out:
# type(freqs) = <class 'dict'>
# len(freqs) = 11346

# %%
freqs.get(('top',1),-1)
# Out:
# 30

# %% [markdown]
# #### Expected output
# ```
# type(freqs) = <class 'dict'>
# len(freqs) = 11346
# ```

# %% [markdown]
# ### Process tweet
# The given function `process_tweet()` tokenizes the tweet into individual words, removes stop words and applies stemming.

# %%
# test the function below
print('This is an example of a positive tweet: \n', train_x[0])
print('\nThis is an example of the processed version of the tweet: \n', process_tweet(train_x[0]))
# Out:
# This is an example of a positive tweet:
#  #FollowFriday @France_Inte @PKuchly57 @Milipol_Paris for being top engaged members in my community this week :)
#
# This is an example of the processed version of the tweet:
#  ['followfriday', 'top', 'engag', 'member', 'commun', 'week', ':)']

# %% [markdown]
# #### Expected output
# ```
# This is an example of a positive tweet:
#  #FollowFriday @France_Inte @PKuchly57 @Milipol_Paris for being top engaged members in my community this week :)
#
# This is an example of the processes version:
#  ['followfriday', 'top', 'engag', 'member', 'commun', 'week', ':)']
# ```

# %% [markdown]
# # Part 1: Logistic regression
#
#
# ### Part 1.1: Sigmoid
# You will learn to use logistic regression for text classification.
# * The sigmoid function is defined as:
#
# $$ h(z) = \frac{1}{1+\exp^{-z}} \tag{1}$$
#
# It maps the input 'z' to a value that ranges between 0 and 1, and so it can be treated as a probability.
#
# <div style="width:image width px; font-size:100%; text-align:center;"><img src='../tmp2/sigmoid_plot.jpg' alt="alternate text" width="width" height="height" style="width:300px;height:200px;" /> Figure 1 </div>

# %% [markdown]
# #### Instructions: Implement the sigmoid function
# * You will want this function to work if z is a scalar as well as if it is an array.

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li><a href="https://docs.scipy.org/doc/numpy/reference/generated/numpy.exp.html" > numpy.exp </a> </li>
#
# </ul>
# </p>

# %%
# UNQ_C1 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def sigmoid(z): 
    '''
    Input:
        z: is the input (can be a scalar or an array)
    Output:
        h: the sigmoid of z
    '''
    
    ### START CODE HERE (REPLACE INSTANCES OF 'None' with your code) ###
    # calculate the sigmoid of z
#     h = 1/(1+math.exp(-z))
    h = []
    for i in z:
        h.append(1/(1+math.exp(-i)))
    ### END CODE HERE ###
    
    return h

# %%
# Testing your function 
if (sigmoid([0])[0] == 0.5):
    print('SUCCESS!')
else:
    print('Oops!')

if (sigmoid([4.92])[0] == 0.9927537604041685):
    print('CORRECT!')
else:
    print('Oops again!')
# Out:
# SUCCESS!
# CORRECT!

# %%
sigmoid(np.array([4.92,0]))
# print(i for i in np.array([0.5,0.5]))
# Out:
# [0.9927537604041685, 0.5]

# %% [markdown]
# ### Logistic regression: regression and a sigmoid
#
# Logistic regression takes a regular linear regression, and applies a sigmoid to the output of the linear regression.
#
# Regression:
# $$z = \theta_0 x_0 + \theta_1 x_1 + \theta_2 x_2 + ... \theta_N x_N$$
# Note that the $\theta$ values are "weights". If you took the Deep Learning Specialization, we referred to the weights with the `w` vector.  In this course, we're using a different variable $\theta$ to refer to the weights.
#
# Logistic regression
# $$ h(z) = \frac{1}{1+\exp^{-z}}$$
# $$z = \theta_0 x_0 + \theta_1 x_1 + \theta_2 x_2 + ... \theta_N x_N$$
# We will refer to 'z' as the 'logits'.

# %% [markdown]
# ### Part 1.2 Cost function and Gradient
#
# The cost function used for logistic regression is the average of the log loss across all training examples:
#
# $$J(\theta) = -\frac{1}{m} \sum_{i=1}^m y^{(i)}\log (h(z(\theta)^{(i)})) + (1-y^{(i)})\log (1-h(z(\theta)^{(i)}))\tag{5} $$
# * $m$ is the number of training examples
# * $y^{(i)}$ is the actual label of the i-th training example.
# * $h(z(\theta)^{(i)})$ is the model's prediction for the i-th training example.
#
# The loss function for a single training example is
# $$ Loss = -1 \times \left( y^{(i)}\log (h(z(\theta)^{(i)})) + (1-y^{(i)})\log (1-h(z(\theta)^{(i)})) \right)$$
#
# * All the $h$ values are between 0 and 1, so the logs will be negative. That is the reason for the factor of -1 applied to the sum of the two loss terms.
# * Note that when the model predicts 1 ($h(z(\theta)) = 1$) and the label $y$ is also 1, the loss for that training example is 0.
# * Similarly, when the model predicts 0 ($h(z(\theta)) = 0$) and the actual label is also 0, the loss for that training example is 0.
# * However, when the model prediction is close to 1 ($h(z(\theta)) = 0.9999$) and the label is 0, the second term of the log loss becomes a large negative number, which is then multiplied by the overall factor of -1 to convert it to a positive loss value. $-1 \times (1 - 0) \times log(1 - 0.9999) \approx 9.2$ The closer the model prediction gets to 1, the larger the loss.

# %%
# verify that when the model predicts close to 1, but the actual label is 0, the loss is a large positive value
-1 * (1 - 0) * np.log(1 - 0.9999) # loss is about 9.2
# Out:
# 9.210340371976294

# %% [markdown]
# * Likewise, if the model predicts close to 0 ($h(z) = 0.0001$) but the actual label is 1, the first term in the loss function becomes a large number: $-1 \times log(0.0001) \approx 9.2$.  The closer the prediction is to zero, the larger the loss.

# %%
# verify that when the model predicts close to 0 but the actual label is 1, the loss is a large positive value
-1 * np.log(0.0001) # loss is about 9.2
# Out:
# 9.210340371976182

# %% [markdown]
# #### Update the weights
#
# To update your weight vector $\theta$, you will apply gradient descent to iteratively improve your model's predictions.
# The gradient of the cost function $J$ with respect to one of the weights $\theta_j$ is:
#
# $$\nabla_{\theta_j}J(\theta) = \frac{1}{m} \sum_{i=1}^m(h^{(i)}-y^{(i)})x_j \tag{5}$$
# * 'i' is the index across all 'm' training examples.
# * 'j' is the index of the weight $\theta_j$, so $x_j$ is the feature associated with weight $\theta_j$
#
# * To update the weight $\theta_j$, we adjust it by subtracting a fraction of the gradient determined by $\alpha$:
# $$\theta_j = \theta_j - \alpha \times \nabla_{\theta_j}J(\theta) $$
# * The learning rate $\alpha$ is a value that we choose to control how big a single update will be.

# %% [markdown]
# ## Instructions: Implement gradient descent function
# * The number of iterations `num_iters` is the number of times that you'll use the entire training set.
# * For each iteration, you'll calculate the cost function using all training examples (there are `m` training examples), and for all features.
# * Instead of updating a single weight $\theta_i$ at a time, we can update all the weights in the column vector:
# $$\mathbf{\theta} = \begin{pmatrix}
# \theta_0
# \\
# \theta_1
# \\
# \theta_2
# \\
# \vdots
# \\
# \theta_n
# \end{pmatrix}$$
# * $\mathbf{\theta}$ has dimensions (n+1, 1), where 'n' is the number of features, and there is one more element for the bias term $\theta_0$ (note that the corresponding feature value $\mathbf{x_0}$ is 1).
# * The 'logits', 'z', are calculated by multiplying the feature matrix 'x' with the weight vector 'theta'.  $z = \mathbf{x}\mathbf{\theta}$
#     * $\mathbf{x}$ has dimensions (m, n+1)
#     * $\mathbf{\theta}$: has dimensions (n+1, 1)
#     * $\mathbf{z}$: has dimensions (m, 1)
# * The prediction 'h', is calculated by applying the sigmoid to each element in 'z': $h(z) = sigmoid(z)$, and has dimensions (m,1).
# * The cost function $J$ is calculated by taking the dot product of the vectors 'y' and 'log(h)'.  Since both 'y' and 'h' are column vectors (m,1), transpose the vector to the left, so that matrix multiplication of a row vector with column vector performs the dot product.
# $$J = \frac{-1}{m} \times \left(\mathbf{y}^T \cdot log(\mathbf{h}) + \mathbf{(1-y)}^T \cdot log(\mathbf{1-h}) \right)$$
# * The update of theta is also vectorized.  Because the dimensions of $\mathbf{x}$ are (m, n+1), and both $\mathbf{h}$ and $\mathbf{y}$ are (m, 1), we need to transpose the $\mathbf{x}$ and place it on the left in order to perform matrix multiplication, which then yields the (n+1, 1) answer we need:
# $$\mathbf{\theta} = \mathbf{\theta} - \frac{\alpha}{m} \times \left( \mathbf{x}^T \cdot \left( \mathbf{h-y} \right) \right)$$

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li>use np.dot for matrix multiplication.</li>
#     <li>To ensure that the fraction -1/m is a decimal value, cast either the numerator or denominator (or both), like `float(1)`, or write `1.` for the float version of 1. </li>
# </ul>
# </p>

# %%
# UNQ_C2 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def gradientDescent(x, y, theta, alpha, num_iters):
    '''
    Input:
        x: matrix of features which is (m,n+1)
        y: corresponding labels of the input matrix x, dimensions (m,1)
        theta: weight vector of dimension (n+1,1)
        alpha: learning rate
        num_iters: number of iterations you want to train your model for
    Output:
        J: the final cost
        theta: your final weight vector
    Hint: you might want to print the cost to make sure that it is going down.
    '''
    ### START CODE HERE (REPLACE INSTANCES OF 'None' with your code) ###
    # get 'm', the number of rows in matrix x
    m = x.shape[0]
    
    for i in range(0, num_iters):
        
        # get z, the dot product of x and theta
        z = np.dot(x,theta) # (m,1) column vector linear regression expression z = theta_zero + theta_one * x0 + theta_two * x2 + ....
        
        # get the sigmoid of z 
        h = np.array(sigmoid(z)).reshape(m,1) #(m,1) column vector size # convert the range to 0 to 1 using sigmoid function
        
        # calculate the cost function
        J = ((np.dot(y.T,np.log(h))) + (np.dot((1-y).T,np.log(1-h))))/(m*(-1))  #−1𝑚×(𝐲𝑇⋅𝑙𝑜𝑔(𝐡)+(1−𝐲)𝑇⋅𝑙𝑜𝑔(1−𝐡))
        
        print('the value of cost function is {} in iteration # {}'.format(J, i))

        # update the weights theta
        theta = theta-((alpha/m)*(np.dot(x.T,(h-y)))) # 𝜃=𝜃−𝛼𝑚×(𝐱𝑇⋅(𝐡−𝐲))
        
    ### END CODE HERE ###
    J = float(J)
    return J, theta

# %%
tmp_X = np.append(np.ones((10, 1)), np.random.rand(10, 2) * 2000, axis=1)
# tmp_X # features (10,3)
theta = np.zeros((3, 1))

t1 =  np.dot(tmp_X,theta) # --> z values for each tweet!

# find h value using sigmoid of z
h1 = np.array(sigmoid(t1)).reshape(10,1)
# expected output
# h1.shape

y1 = (np.random.rand(10, 1) > 0.35).astype(float)
# y1.shape
J1 =  ((np.dot(y1.T,np.log(h1))) + (np.dot((1-y1).T,np.log(1-h1)))/(10*(-1)))
# np.dot((1-y1).T,np.log(1-h1))
# float(J1)

# %%
# Check the function
# Construct a synthetic test case using numpy PRNG functions
np.random.seed(1)
# X input is 10 x 3 with ones for the bias terms
tmp_X = np.append(np.ones((10, 1)), np.random.rand(10, 2) * 2000, axis=1)
# Y Labels are 10 x 1
tmp_Y = (np.random.rand(10, 1) > 0.35).astype(float)

# Apply gradient descent
tmp_J, tmp_theta = gradientDescent(tmp_X, tmp_Y, np.zeros((3, 1)), 1e-8, 700) #features, labels, theta/weights, alpha/learning rate, iterations
print(f"The cost after training is {tmp_J:.8f}.")
print(f"The resulting vector of weights is {[round(t, 8) for t in np.squeeze(tmp_theta)]}")
# Out:
# the value of cost function is [[0.69314718]] in iteration # 0
# the value of cost function is [[0.69305407]] in iteration # 1
# the value of cost function is [[0.69296151]] in iteration # 2
# the value of cost function is [[0.6928695]] in iteration # 3
# the value of cost function is [[0.69277802]] in iteration # 4
# the value of cost function is [[0.69268708]] in iteration # 5
# the value of cost function is [[0.69259667]] in iteration # 6
# the value of cost function is [[0.69250679]] in iteration # 7
# the value of cost function is [[0.69241743]] in iteration # 8
# the value of cost function is [[0.69232859]] in iteration # 9
# the value of cost function is [[0.69224027]] in iteration # 10
# the value of cost function is [[0.69215246]] in iteration # 11
# the value of cost function is [[0.69206515]] in iteration # 12
# the value of cost function is [[0.69197836]] in iteration # 13
# the value of cost function is [[0.69189206]] in iteration # 14
# the value of cost function is [[0.69180626]] in iteration # 15
# the value of cost function is [[0.69172096]] in iteration # 16
# the value of cost function is [[0.69163614]] in iteration # 17
# the value of cost function is [[0.69155182]] in iteration # 18
# the value of cost function is [[0.69146797]] in iteration # 19
# the value of cost function is [[0.69138461]] in iteration # 20
# the value of cost function is [[0.69130172]] in iteration # 21
# the value of cost function is [[0.6912193]] in iteration # 22
# the value of cost function is [[0.69113736]] in iteration # 23
# the value of cost function is [[0.69105588]] in iteration # 24
# the value of cost function is [[0.69097486]] in iteration # 25
# the value of cost function is [[0.6908943]] in iteration # 26
# the value of cost function is [[0.6908142]] in iteration # 27
# the value of cost function is [[0.69073455]] in iteration # 28
# the value of cost function is [[0.69065535]] in iteration # 29
# the value of cost function is [[0.69057659]] in iteration # 30
# the value of cost function is [[0.69049828]] in iteration # 31
# the value of cost function is [[0.69042041]] in iteration # 32
# the value of cost function is [[0.69034297]] in iteration # 33
# the value of cost function is [[0.69026597]] in iteration # 34
# the value of cost function is [[0.6901894]] in iteration # 35
# the value of cost function is [[0.69011325]] in iteration # 36
# the value of cost function is [[0.69003753]] in iteration # 37
# the value of cost function is [[0.68996223]] in iteration # 38
# the value of cost function is [[0.68988734]] in iteration # 39
# the value of cost function is [[0.68981287]] in iteration # 40
# the value of cost function is [[0.68973881]] in iteration # 41
# the value of cost function is [[0.68966516]] in iteration # 42
# the value of cost function is [[0.68959192]] in iteration # 43
# the value of cost function is [[0.68951908]] in iteration # 44
# the value of cost function is [[0.68944664]] in iteration # 45
# the value of cost function is [[0.68937459]] in iteration # 46
# the value of cost function is [[0.68930294]] in iteration # 47
# the value of cost function is [[0.68923168]] in iteration # 48
# the value of cost function is [[0.68916081]] in iteration # 49
# the value of cost function is [[0.68909032]] in iteration # 50
# the value of cost function is [[0.68902022]] in iteration # 51
# the value of cost function is [[0.6889505]] in iteration # 52
# the value of cost function is [[0.68888115]] in iteration # 53
# the value of cost function is [[0.68881218]] in iteration # 54
# the value of cost function is [[0.68874358]] in iteration # 55
# the value of cost function is [[0.68867534]] in iteration # 56
# the value of cost function is [[0.68860748]] in iteration # 57
# the value of cost function is [[0.68853998]] in iteration # 58
# the value of cost function is [[0.68847284]] in iteration # 59
# the value of cost function is [[0.68840605]] in iteration # 60
# the value of cost function is [[0.68833963]] in iteration # 61
# the value of cost function is [[0.68827355]] in iteration # 62
# the value of cost function is [[0.68820783]] in iteration # 63
# the value of cost function is [[0.68814245]] in iteration # 64
# the value of cost function is [[0.68807742]] in iteration # 65
# the value of cost function is [[0.68801274]] in iteration # 66
# the value of cost function is [[0.68794839]] in iteration # 67
# the value of cost function is [[0.68788438]] in iteration # 68
# the value of cost function is [[0.68782071]] in iteration # 69
# the value of cost function is [[0.68775737]] in iteration # 70
# the value of cost function is [[0.68769436]] in iteration # 71
# the value of cost function is [[0.68763168]] in iteration # 72
# the value of cost function is [[0.68756933]] in iteration # 73
# the value of cost function is [[0.68750729]] in iteration # 74
# the value of cost function is [[0.68744558]] in iteration # 75
# the value of cost function is [[0.68738419]] in iteration # 76
# the value of cost function is [[0.68732312]] in iteration # 77
# the value of cost function is [[0.68726236]] in iteration # 78
# the value of cost function is [[0.68720191]] in iteration # 79
# the value of cost function is [[0.68714177]] in iteration # 80
# the value of cost function is [[0.68708194]] in iteration # 81
# the value of cost function is [[0.68702242]] in iteration # 82
# the value of cost function is [[0.6869632]] in iteration # 83
# the value of cost function is [[0.68690427]] in iteration # 84
# the value of cost function is [[0.68684565]] in iteration # 85
# the value of cost function is [[0.68678733]] in iteration # 86
# the value of cost function is [[0.6867293]] in iteration # 87
# the value of cost function is [[0.68667156]] in iteration # 88
# the value of cost function is [[0.68661411]] in iteration # 89
# the value of cost function is [[0.68655695]] in iteration # 90
# the value of cost function is [[0.68650007]] in iteration # 91
# the value of cost function is [[0.68644348]] in iteration # 92
# the value of cost function is [[0.68638717]] in iteration # 93
# the value of cost function is [[0.68633114]] in iteration # 94
# the value of cost function is [[0.68627539]] in iteration # 95
# the value of cost function is [[0.68621992]] in iteration # 96
# the value of cost function is [[0.68616471]] in iteration # 97
# the value of cost function is [[0.68610978]] in iteration # 98
# the value of cost function is [[0.68605512]] in iteration # 99
# the value of cost function is [[0.68600073]] in iteration # 100
# the value of cost function is [[0.68594661]] in iteration # 101
# the value of cost function is [[0.68589275]] in iteration # 102
# the value of cost function is [[0.68583915]] in iteration # 103
# the value of cost function is [[0.68578581]] in iteration # 104
# the value of cost function is [[0.68573273]] in iteration # 105
# the value of cost function is [[0.6856799]] in iteration # 106
# the value of cost function is [[0.68562733]] in iteration # 107
# the value of cost function is [[0.68557501]] in iteration # 108
# the value of cost function is [[0.68552295]] in iteration # 109
# the value of cost function is [[0.68547113]] in iteration # 110
# the value of cost function is [[0.68541956]] in iteration # 111
# the value of cost function is [[0.68536824]] in iteration # 112
# the value of cost function is [[0.68531716]] in iteration # 113
# the value of cost function is [[0.68526632]] in iteration # 114
# the value of cost function is [[0.68521573]] in iteration # 115
# the value of cost function is [[0.68516537]] in iteration # 116
# the value of cost function is [[0.68511525]] in iteration # 117
# the value of cost function is [[0.68506536]] in iteration # 118
# the value of cost function is [[0.68501571]] in iteration # 119
# the value of cost function is [[0.68496629]] in iteration # 120
# the value of cost function is [[0.6849171]] in iteration # 121
# the value of cost function is [[0.68486814]] in iteration # 122
# the value of cost function is [[0.6848194]] in iteration # 123
# the value of cost function is [[0.68477089]] in iteration # 124
# the value of cost function is [[0.68472261]] in iteration # 125
# the value of cost function is [[0.68467454]] in iteration # 126
# the value of cost function is [[0.6846267]] in iteration # 127
# the value of cost function is [[0.68457907]] in iteration # 128
# the value of cost function is [[0.68453167]] in iteration # 129
# the value of cost function is [[0.68448448]] in iteration # 130
# the value of cost function is [[0.6844375]] in iteration # 131
# the value of cost function is [[0.68439073]] in iteration # 132
# the value of cost function is [[0.68434418]] in iteration # 133
# the value of cost function is [[0.68429784]] in iteration # 134
# the value of cost function is [[0.6842517]] in iteration # 135
# the value of cost function is [[0.68420577]] in iteration # 136
# the value of cost function is [[0.68416005]] in iteration # 137
# the value of cost function is [[0.68411453]] in iteration # 138
# the value of cost function is [[0.68406921]] in iteration # 139
# the value of cost function is [[0.68402409]] in iteration # 140
# the value of cost function is [[0.68397918]] in iteration # 141
# the value of cost function is [[0.68393446]] in iteration # 142
# the value of cost function is [[0.68388993]] in iteration # 143
# the value of cost function is [[0.6838456]] in iteration # 144
# the value of cost function is [[0.68380147]] in iteration # 145
# the value of cost function is [[0.68375753]] in iteration # 146
# the value of cost function is [[0.68371378]] in iteration # 147
# the value of cost function is [[0.68367022]] in iteration # 148
# the value of cost function is [[0.68362684]] in iteration # 149
# the value of cost function is [[0.68358366]] in iteration # 150
# the value of cost function is [[0.68354066]] in iteration # 151
# the value of cost function is [[0.68349784]] in iteration # 152
# the value of cost function is [[0.68345521]] in iteration # 153
# the value of cost function is [[0.68341275]] in iteration # 154
# the value of cost function is [[0.68337048]] in iteration # 155
# the value of cost function is [[0.68332839]] in iteration # 156
# the value of cost function is [[0.68328647]] in iteration # 157
# the value of cost function is [[0.68324474]] in iteration # 158
# the value of cost function is [[0.68320317]] in iteration # 159
# the value of cost function is [[0.68316178]] in iteration # 160
# the value of cost function is [[0.68312057]] in iteration # 161
# the value of cost function is [[0.68307952]] in iteration # 162
# the value of cost function is [[0.68303865]] in iteration # 163
# the value of cost function is [[0.68299794]] in iteration # 164
# the value of cost function is [[0.68295741]] in iteration # 165
# the value of cost function is [[0.68291704]] in iteration # 166
# the value of cost function is [[0.68287683]] in iteration # 167
# the value of cost function is [[0.68283679]] in iteration # 168
# the value of cost function is [[0.68279691]] in iteration # 169
# the value of cost function is [[0.6827572]] in iteration # 170
# the value of cost function is [[0.68271764]] in iteration # 171
# the value of cost function is [[0.68267825]] in iteration # 172
# the value of cost function is [[0.68263901]] in iteration # 173
# the value of cost function is [[0.68259993]] in iteration # 174
# the value of cost function is [[0.68256101]] in iteration # 175
# the value of cost function is [[0.68252224]] in iteration # 176
# the value of cost function is [[0.68248363]] in iteration # 177
# the value of cost function is [[0.68244517]] in iteration # 178
# the value of cost function is [[0.68240686]] in iteration # 179
# the value of cost function is [[0.6823687]] in iteration # 180
# the value of cost function is [[0.6823307]] in iteration # 181
# the value of cost function is [[0.68229284]] in iteration # 182
# the value of cost function is [[0.68225513]] in iteration # 183
# the value of cost function is [[0.68221756]] in iteration # 184
# the value of cost function is [[0.68218015]] in iteration # 185
# the value of cost function is [[0.68214287]] in iteration # 186
# the value of cost function is [[0.68210574]] in iteration # 187
# the value of cost function is [[0.68206876]] in iteration # 188
# the value of cost function is [[0.68203191]] in iteration # 189
# the value of cost function is [[0.6819952]] in iteration # 190
# the value of cost function is [[0.68195864]] in iteration # 191
# the value of cost function is [[0.68192221]] in iteration # 192
# the value of cost function is [[0.68188592]] in iteration # 193
# the value of cost function is [[0.68184977]] in iteration # 194
# the value of cost function is [[0.68181375]] in iteration # 195
# the value of cost function is [[0.68177787]] in iteration # 196
# the value of cost function is [[0.68174212]] in iteration # 197
# the value of cost function is [[0.68170651]] in iteration # 198
# the value of cost function is [[0.68167102]] in iteration # 199
# the value of cost function is [[0.68163567]] in iteration # 200
# the value of cost function is [[0.68160045]] in iteration # 201
# the value of cost function is [[0.68156536]] in iteration # 202
# the value of cost function is [[0.68153039]] in iteration # 203
# the value of cost function is [[0.68149555]] in iteration # 204
# the value of cost function is [[0.68146084]] in iteration # 205
# the value of cost function is [[0.68142626]] in iteration # 206
# the value of cost function is [[0.6813918]] in iteration # 207
# the value of cost function is [[0.68135746]] in iteration # 208
# the value of cost function is [[0.68132325]] in iteration # 209
# the value of cost function is [[0.68128916]] in iteration # 210
# the value of cost function is [[0.68125519]] in iteration # 211
# the value of cost function is [[0.68122134]] in iteration # 212
# the value of cost function is [[0.68118761]] in iteration # 213
# the value of cost function is [[0.68115399]] in iteration # 214
# the value of cost function is [[0.6811205]] in iteration # 215
# the value of cost function is [[0.68108712]] in iteration # 216
# the value of cost function is [[0.68105386]] in iteration # 217
# the value of cost function is [[0.68102072]] in iteration # 218
# the value of cost function is [[0.68098769]] in iteration # 219
# the value of cost function is [[0.68095477]] in iteration # 220
# the value of cost function is [[0.68092197]] in iteration # 221
# the value of cost function is [[0.68088928]] in iteration # 222
# the value of cost function is [[0.6808567]] in iteration # 223
# the value of cost function is [[0.68082423]] in iteration # 224
# the value of cost function is [[0.68079187]] in iteration # 225
# the value of cost function is [[0.68075962]] in iteration # 226
# the value of cost function is [[0.68072748]] in iteration # 227
# the value of cost function is [[0.68069545]] in iteration # 228
# the value of cost function is [[0.68066352]] in iteration # 229
# the value of cost function is [[0.6806317]] in iteration # 230
# the value of cost function is [[0.68059999]] in iteration # 231
# the value of cost function is [[0.68056838]] in iteration # 232
# the value of cost function is [[0.68053687]] in iteration # 233
# the value of cost function is [[0.68050547]] in iteration # 234
# the value of cost function is [[0.68047417]] in iteration # 235
# the value of cost function is [[0.68044297]] in iteration # 236
# the value of cost function is [[0.68041187]] in iteration # 237
# the value of cost function is [[0.68038088]] in iteration # 238
# the value of cost function is [[0.68034998]] in iteration # 239
# the value of cost function is [[0.68031918]] in iteration # 240
# the value of cost function is [[0.68028848]] in iteration # 241
# the value of cost function is [[0.68025788]] in iteration # 242
# the value of cost function is [[0.68022738]] in iteration # 243
# the value of cost function is [[0.68019697]] in iteration # 244
# the value of cost function is [[0.68016666]] in iteration # 245
# the value of cost function is [[0.68013644]] in iteration # 246
# the value of cost function is [[0.68010632]] in iteration # 247
# the value of cost function is [[0.68007629]] in iteration # 248
# the value of cost function is [[0.68004635]] in iteration # 249
# the value of cost function is [[0.68001651]] in iteration # 250
# the value of cost function is [[0.67998676]] in iteration # 251
# the value of cost function is [[0.6799571]] in iteration # 252
# the value of cost function is [[0.67992753]] in iteration # 253
# the value of cost function is [[0.67989805]] in iteration # 254
# the value of cost function is [[0.67986866]] in iteration # 255
# the value of cost function is [[0.67983936]] in iteration # 256
# the value of cost function is [[0.67981014]] in iteration # 257
# the value of cost function is [[0.67978102]] in iteration # 258
# the value of cost function is [[0.67975198]] in iteration # 259
# the value of cost function is [[0.67972303]] in iteration # 260
# the value of cost function is [[0.67969416]] in iteration # 261
# the value of cost function is [[0.67966538]] in iteration # 262
# the value of cost function is [[0.67963668]] in iteration # 263
# the value of cost function is [[0.67960807]] in iteration # 264
# the value of cost function is [[0.67957954]] in iteration # 265
# the value of cost function is [[0.67955109]] in iteration # 266
# the value of cost function is [[0.67952272]] in iteration # 267
# the value of cost function is [[0.67949444]] in iteration # 268
# the value of cost function is [[0.67946624]] in iteration # 269
# the value of cost function is [[0.67943812]] in iteration # 270
# the value of cost function is [[0.67941008]] in iteration # 271
# the value of cost function is [[0.67938212]] in iteration # 272
# the value of cost function is [[0.67935423]] in iteration # 273
# the value of cost function is [[0.67932643]] in iteration # 274
# the value of cost function is [[0.6792987]] in iteration # 275
# the value of cost function is [[0.67927106]] in iteration # 276
# the value of cost function is [[0.67924348]] in iteration # 277
# the value of cost function is [[0.67921599]] in iteration # 278
# the value of cost function is [[0.67918857]] in iteration # 279
# the value of cost function is [[0.67916123]] in iteration # 280
# the value of cost function is [[0.67913396]] in iteration # 281
# the value of cost function is [[0.67910676]] in iteration # 282
# the value of cost function is [[0.67907964]] in iteration # 283
# the value of cost function is [[0.67905259]] in iteration # 284
# the value of cost function is [[0.67902562]] in iteration # 285
# the value of cost function is [[0.67899872]] in iteration # 286
# the value of cost function is [[0.67897189]] in iteration # 287
# the value of cost function is [[0.67894513]] in iteration # 288
# the value of cost function is [[0.67891844]] in iteration # 289
# the value of cost function is [[0.67889182]] in iteration # 290
# the value of cost function is [[0.67886527]] in iteration # 291
# the value of cost function is [[0.67883879]] in iteration # 292
# the value of cost function is [[0.67881238]] in iteration # 293
# the value of cost function is [[0.67878604]] in iteration # 294
# the value of cost function is [[0.67875977]] in iteration # 295
# the value of cost function is [[0.67873357]] in iteration # 296
# the value of cost function is [[0.67870743]] in iteration # 297
# the value of cost function is [[0.67868136]] in iteration # 298
# the value of cost function is [[0.67865535]] in iteration # 299
# the value of cost function is [[0.67862941]] in iteration # 300
# the value of cost function is [[0.67860354]] in iteration # 301
# the value of cost function is [[0.67857773]] in iteration # 302
# the value of cost function is [[0.67855199]] in iteration # 303
# the value of cost function is [[0.67852631]] in iteration # 304
# the value of cost function is [[0.67850069]] in iteration # 305
# the value of cost function is [[0.67847514]] in iteration # 306
# the value of cost function is [[0.67844965]] in iteration # 307
# the value of cost function is [[0.67842422]] in iteration # 308
# the value of cost function is [[0.67839885]] in iteration # 309
# the value of cost function is [[0.67837355]] in iteration # 310
# the value of cost function is [[0.67834831]] in iteration # 311
# the value of cost function is [[0.67832313]] in iteration # 312
# the value of cost function is [[0.678298]] in iteration # 313
# the value of cost function is [[0.67827294]] in iteration # 314
# the value of cost function is [[0.67824794]] in iteration # 315
# the value of cost function is [[0.678223]] in iteration # 316
# the value of cost function is [[0.67819812]] in iteration # 317
# the value of cost function is [[0.67817329]] in iteration # 318
# the value of cost function is [[0.67814852]] in iteration # 319
# the value of cost function is [[0.67812381]] in iteration # 320
# the value of cost function is [[0.67809916]] in iteration # 321
# the value of cost function is [[0.67807457]] in iteration # 322
# the value of cost function is [[0.67805003]] in iteration # 323
# the value of cost function is [[0.67802554]] in iteration # 324
# the value of cost function is [[0.67800112]] in iteration # 325
# the value of cost function is [[0.67797675]] in iteration # 326
# the value of cost function is [[0.67795243]] in iteration # 327
# the value of cost function is [[0.67792817]] in iteration # 328
# the value of cost function is [[0.67790396]] in iteration # 329
# the value of cost function is [[0.67787981]] in iteration # 330
# the value of cost function is [[0.67785571]] in iteration # 331
# the value of cost function is [[0.67783166]] in iteration # 332
# the value of cost function is [[0.67780767]] in iteration # 333
# the value of cost function is [[0.67778373]] in iteration # 334
# the value of cost function is [[0.67775984]] in iteration # 335
# the value of cost function is [[0.677736]] in iteration # 336
# the value of cost function is [[0.67771222]] in iteration # 337
# the value of cost function is [[0.67768848]] in iteration # 338
# the value of cost function is [[0.6776648]] in iteration # 339
# the value of cost function is [[0.67764117]] in iteration # 340
# the value of cost function is [[0.67761759]] in iteration # 341
# the value of cost function is [[0.67759406]] in iteration # 342
# the value of cost function is [[0.67757058]] in iteration # 343
# the value of cost function is [[0.67754714]] in iteration # 344
# the value of cost function is [[0.67752376]] in iteration # 345
# the value of cost function is [[0.67750042]] in iteration # 346
# the value of cost function is [[0.67747714]] in iteration # 347
# the value of cost function is [[0.6774539]] in iteration # 348
# the value of cost function is [[0.67743071]] in iteration # 349
# the value of cost function is [[0.67740756]] in iteration # 350
# the value of cost function is [[0.67738447]] in iteration # 351
# the value of cost function is [[0.67736142]] in iteration # 352
# the value of cost function is [[0.67733842]] in iteration # 353
# the value of cost function is [[0.67731546]] in iteration # 354
# the value of cost function is [[0.67729255]] in iteration # 355
# the value of cost function is [[0.67726968]] in iteration # 356
# the value of cost function is [[0.67724686]] in iteration # 357
# the value of cost function is [[0.67722409]] in iteration # 358
# the value of cost function is [[0.67720136]] in iteration # 359
# the value of cost function is [[0.67717868]] in iteration # 360
# the value of cost function is [[0.67715603]] in iteration # 361
# the value of cost function is [[0.67713344]] in iteration # 362
# the value of cost function is [[0.67711088]] in iteration # 363
# the value of cost function is [[0.67708837]] in iteration # 364
# the value of cost function is [[0.67706591]] in iteration # 365
# the value of cost function is [[0.67704348]] in iteration # 366
# the value of cost function is [[0.6770211]] in iteration # 367
# the value of cost function is [[0.67699876]] in iteration # 368
# the value of cost function is [[0.67697647]] in iteration # 369
# the value of cost function is [[0.67695421]] in iteration # 370
# the value of cost function is [[0.676932]] in iteration # 371
# the value of cost function is [[0.67690983]] in iteration # 372
# the value of cost function is [[0.67688769]] in iteration # 373
# the value of cost function is [[0.6768656]] in iteration # 374
# the value of cost function is [[0.67684355]] in iteration # 375
# the value of cost function is [[0.67682154]] in iteration # 376
# the value of cost function is [[0.67679957]] in iteration # 377
# the value of cost function is [[0.67677764]] in iteration # 378
# the value of cost function is [[0.67675575]] in iteration # 379
# the value of cost function is [[0.6767339]] in iteration # 380
# the value of cost function is [[0.67671209]] in iteration # 381
# the value of cost function is [[0.67669032]] in iteration # 382
# the value of cost function is [[0.67666858]] in iteration # 383
# the value of cost function is [[0.67664688]] in iteration # 384
# the value of cost function is [[0.67662522]] in iteration # 385
# the value of cost function is [[0.6766036]] in iteration # 386
# the value of cost function is [[0.67658202]] in iteration # 387
# the value of cost function is [[0.67656047]] in iteration # 388
# the value of cost function is [[0.67653897]] in iteration # 389
# the value of cost function is [[0.67651749]] in iteration # 390
# the value of cost function is [[0.67649606]] in iteration # 391
# the value of cost function is [[0.67647466]] in iteration # 392
# the value of cost function is [[0.6764533]] in iteration # 393
# the value of cost function is [[0.67643197]] in iteration # 394
# the value of cost function is [[0.67641068]] in iteration # 395
# the value of cost function is [[0.67638942]] in iteration # 396
# the value of cost function is [[0.6763682]] in iteration # 397
# the value of cost function is [[0.67634702]] in iteration # 398
# the value of cost function is [[0.67632587]] in iteration # 399
# the value of cost function is [[0.67630475]] in iteration # 400
# the value of cost function is [[0.67628367]] in iteration # 401
# the value of cost function is [[0.67626263]] in iteration # 402
# the value of cost function is [[0.67624161]] in iteration # 403
# the value of cost function is [[0.67622063]] in iteration # 404
# the value of cost function is [[0.67619969]] in iteration # 405
# the value of cost function is [[0.67617878]] in iteration # 406
# the value of cost function is [[0.6761579]] in iteration # 407
# the value of cost function is [[0.67613705]] in iteration # 408
# the value of cost function is [[0.67611624]] in iteration # 409
# the value of cost function is [[0.67609546]] in iteration # 410
# the value of cost function is [[0.67607472]] in iteration # 411
# the value of cost function is [[0.676054]] in iteration # 412
# the value of cost function is [[0.67603332]] in iteration # 413
# the value of cost function is [[0.67601267]] in iteration # 414
# the value of cost function is [[0.67599205]] in iteration # 415
# the value of cost function is [[0.67597146]] in iteration # 416
# the value of cost function is [[0.6759509]] in iteration # 417
# the value of cost function is [[0.67593038]] in iteration # 418
# the value of cost function is [[0.67590988]] in iteration # 419
# the value of cost function is [[0.67588942]] in iteration # 420
# the value of cost function is [[0.67586899]] in iteration # 421
# the value of cost function is [[0.67584858]] in iteration # 422
# the value of cost function is [[0.67582821]] in iteration # 423
# the value of cost function is [[0.67580787]] in iteration # 424
# the value of cost function is [[0.67578756]] in iteration # 425
# the value of cost function is [[0.67576727]] in iteration # 426
# the value of cost function is [[0.67574702]] in iteration # 427
# the value of cost function is [[0.6757268]] in iteration # 428
# the value of cost function is [[0.6757066]] in iteration # 429
# the value of cost function is [[0.67568643]] in iteration # 430
# the value of cost function is [[0.6756663]] in iteration # 431
# the value of cost function is [[0.67564619]] in iteration # 432
# the value of cost function is [[0.67562611]] in iteration # 433
# the value of cost function is [[0.67560606]] in iteration # 434
# the value of cost function is [[0.67558603]] in iteration # 435
# the value of cost function is [[0.67556604]] in iteration # 436
# the value of cost function is [[0.67554607]] in iteration # 437
# the value of cost function is [[0.67552613]] in iteration # 438
# the value of cost function is [[0.67550622]] in iteration # 439
# the value of cost function is [[0.67548633]] in iteration # 440
# the value of cost function is [[0.67546648]] in iteration # 441
# the value of cost function is [[0.67544665]] in iteration # 442
# the value of cost function is [[0.67542684]] in iteration # 443
# the value of cost function is [[0.67540707]] in iteration # 444
# the value of cost function is [[0.67538731]] in iteration # 445
# the value of cost function is [[0.67536759]] in iteration # 446
# the value of cost function is [[0.67534789]] in iteration # 447
# the value of cost function is [[0.67532822]] in iteration # 448
# the value of cost function is [[0.67530858]] in iteration # 449
# the value of cost function is [[0.67528896]] in iteration # 450
# the value of cost function is [[0.67526936]] in iteration # 451
# the value of cost function is [[0.67524979]] in iteration # 452
# the value of cost function is [[0.67523025]] in iteration # 453
# the value of cost function is [[0.67521073]] in iteration # 454
# the value of cost function is [[0.67519124]] in iteration # 455
# the value of cost function is [[0.67517177]] in iteration # 456
# the value of cost function is [[0.67515233]] in iteration # 457
# the value of cost function is [[0.67513291]] in iteration # 458
# the value of cost function is [[0.67511352]] in iteration # 459
# the value of cost function is [[0.67509415]] in iteration # 460
# the value of cost function is [[0.6750748]] in iteration # 461
# the value of cost function is [[0.67505548]] in iteration # 462
# the value of cost function is [[0.67503618]] in iteration # 463
# the value of cost function is [[0.67501691]] in iteration # 464
# the value of cost function is [[0.67499766]] in iteration # 465
# the value of cost function is [[0.67497844]] in iteration # 466
# the value of cost function is [[0.67495923]] in iteration # 467
# the value of cost function is [[0.67494005]] in iteration # 468
# the value of cost function is [[0.6749209]] in iteration # 469
# the value of cost function is [[0.67490177]] in iteration # 470
# the value of cost function is [[0.67488266]] in iteration # 471
# the value of cost function is [[0.67486357]] in iteration # 472
# the value of cost function is [[0.67484451]] in iteration # 473
# the value of cost function is [[0.67482546]] in iteration # 474
# the value of cost function is [[0.67480645]] in iteration # 475
# the value of cost function is [[0.67478745]] in iteration # 476
# the value of cost function is [[0.67476848]] in iteration # 477
# the value of cost function is [[0.67474952]] in iteration # 478
# the value of cost function is [[0.67473059]] in iteration # 479
# the value of cost function is [[0.67471168]] in iteration # 480
# the value of cost function is [[0.6746928]] in iteration # 481
# the value of cost function is [[0.67467393]] in iteration # 482
# the value of cost function is [[0.67465509]] in iteration # 483
# the value of cost function is [[0.67463627]] in iteration # 484
# the value of cost function is [[0.67461747]] in iteration # 485
# the value of cost function is [[0.67459869]] in iteration # 486
# the value of cost function is [[0.67457993]] in iteration # 487
# the value of cost function is [[0.67456119]] in iteration # 488
# the value of cost function is [[0.67454247]] in iteration # 489
# the value of cost function is [[0.67452378]] in iteration # 490
# the value of cost function is [[0.6745051]] in iteration # 491
# the value of cost function is [[0.67448645]] in iteration # 492
# the value of cost function is [[0.67446781]] in iteration # 493
# the value of cost function is [[0.6744492]] in iteration # 494
# the value of cost function is [[0.6744306]] in iteration # 495
# the value of cost function is [[0.67441203]] in iteration # 496
# the value of cost function is [[0.67439348]] in iteration # 497
# the value of cost function is [[0.67437494]] in iteration # 498
# the value of cost function is [[0.67435643]] in iteration # 499
# the value of cost function is [[0.67433793]] in iteration # 500
# the value of cost function is [[0.67431946]] in iteration # 501
# the value of cost function is [[0.674301]] in iteration # 502
# the value of cost function is [[0.67428257]] in iteration # 503
# the value of cost function is [[0.67426415]] in iteration # 504
# the value of cost function is [[0.67424575]] in iteration # 505
# the value of cost function is [[0.67422737]] in iteration # 506
# the value of cost function is [[0.67420901]] in iteration # 507
# the value of cost function is [[0.67419067]] in iteration # 508
# the value of cost function is [[0.67417235]] in iteration # 509
# the value of cost function is [[0.67415405]] in iteration # 510
# the value of cost function is [[0.67413576]] in iteration # 511
# the value of cost function is [[0.6741175]] in iteration # 512
# the value of cost function is [[0.67409925]] in iteration # 513
# the value of cost function is [[0.67408102]] in iteration # 514
# the value of cost function is [[0.67406281]] in iteration # 515
# the value of cost function is [[0.67404461]] in iteration # 516
# the value of cost function is [[0.67402644]] in iteration # 517
# the value of cost function is [[0.67400828]] in iteration # 518
# the value of cost function is [[0.67399014]] in iteration # 519
# the value of cost function is [[0.67397202]] in iteration # 520
# the value of cost function is [[0.67395391]] in iteration # 521
# the value of cost function is [[0.67393583]] in iteration # 522
# the value of cost function is [[0.67391776]] in iteration # 523
# the value of cost function is [[0.67389971]] in iteration # 524
# the value of cost function is [[0.67388167]] in iteration # 525
# the value of cost function is [[0.67386366]] in iteration # 526
# the value of cost function is [[0.67384566]] in iteration # 527
# the value of cost function is [[0.67382767]] in iteration # 528
# the value of cost function is [[0.67380971]] in iteration # 529
# the value of cost function is [[0.67379176]] in iteration # 530
# the value of cost function is [[0.67377383]] in iteration # 531
# the value of cost function is [[0.67375591]] in iteration # 532
# the value of cost function is [[0.67373801]] in iteration # 533
# the value of cost function is [[0.67372013]] in iteration # 534
# the value of cost function is [[0.67370226]] in iteration # 535
# the value of cost function is [[0.67368441]] in iteration # 536
# the value of cost function is [[0.67366658]] in iteration # 537
# the value of cost function is [[0.67364876]] in iteration # 538
# the value of cost function is [[0.67363096]] in iteration # 539
# the value of cost function is [[0.67361318]] in iteration # 540
# the value of cost function is [[0.67359541]] in iteration # 541
# the value of cost function is [[0.67357766]] in iteration # 542
# the value of cost function is [[0.67355992]] in iteration # 543
# the value of cost function is [[0.6735422]] in iteration # 544
# the value of cost function is [[0.6735245]] in iteration # 545
# the value of cost function is [[0.67350681]] in iteration # 546
# the value of cost function is [[0.67348913]] in iteration # 547
# the value of cost function is [[0.67347147]] in iteration # 548
# the value of cost function is [[0.67345383]] in iteration # 549
# the value of cost function is [[0.6734362]] in iteration # 550
# the value of cost function is [[0.67341859]] in iteration # 551
# the value of cost function is [[0.67340099]] in iteration # 552
# the value of cost function is [[0.67338341]] in iteration # 553
# the value of cost function is [[0.67336584]] in iteration # 554
# the value of cost function is [[0.67334829]] in iteration # 555
# the value of cost function is [[0.67333076]] in iteration # 556
# the value of cost function is [[0.67331323]] in iteration # 557
# the value of cost function is [[0.67329573]] in iteration # 558
# the value of cost function is [[0.67327823]] in iteration # 559
# the value of cost function is [[0.67326076]] in iteration # 560
# the value of cost function is [[0.67324329]] in iteration # 561
# the value of cost function is [[0.67322584]] in iteration # 562
# the value of cost function is [[0.67320841]] in iteration # 563
# the value of cost function is [[0.67319099]] in iteration # 564
# the value of cost function is [[0.67317358]] in iteration # 565
# the value of cost function is [[0.67315619]] in iteration # 566
# the value of cost function is [[0.67313882]] in iteration # 567
# the value of cost function is [[0.67312145]] in iteration # 568
# the value of cost function is [[0.6731041]] in iteration # 569
# the value of cost function is [[0.67308677]] in iteration # 570
# the value of cost function is [[0.67306945]] in iteration # 571
# the value of cost function is [[0.67305214]] in iteration # 572
# the value of cost function is [[0.67303485]] in iteration # 573
# the value of cost function is [[0.67301757]] in iteration # 574
# the value of cost function is [[0.6730003]] in iteration # 575
# the value of cost function is [[0.67298305]] in iteration # 576
# the value of cost function is [[0.67296581]] in iteration # 577
# the value of cost function is [[0.67294859]] in iteration # 578
# the value of cost function is [[0.67293138]] in iteration # 579
# the value of cost function is [[0.67291418]] in iteration # 580
# the value of cost function is [[0.67289699]] in iteration # 581
# the value of cost function is [[0.67287982]] in iteration # 582
# the value of cost function is [[0.67286266]] in iteration # 583
# the value of cost function is [[0.67284552]] in iteration # 584
# the value of cost function is [[0.67282839]] in iteration # 585
# the value of cost function is [[0.67281127]] in iteration # 586
# the value of cost function is [[0.67279416]] in iteration # 587
# the value of cost function is [[0.67277707]] in iteration # 588
# the value of cost function is [[0.67275999]] in iteration # 589
# the value of cost function is [[0.67274292]] in iteration # 590
# the value of cost function is [[0.67272587]] in iteration # 591
# the value of cost function is [[0.67270883]] in iteration # 592
# the value of cost function is [[0.6726918]] in iteration # 593
# the value of cost function is [[0.67267478]] in iteration # 594
# the value of cost function is [[0.67265778]] in iteration # 595
# the value of cost function is [[0.67264079]] in iteration # 596
# the value of cost function is [[0.67262381]] in iteration # 597
# the value of cost function is [[0.67260684]] in iteration # 598
# the value of cost function is [[0.67258989]] in iteration # 599
# the value of cost function is [[0.67257295]] in iteration # 600
# the value of cost function is [[0.67255602]] in iteration # 601
# the value of cost function is [[0.6725391]] in iteration # 602
# the value of cost function is [[0.6725222]] in iteration # 603
# the value of cost function is [[0.67250531]] in iteration # 604
# the value of cost function is [[0.67248843]] in iteration # 605
# the value of cost function is [[0.67247156]] in iteration # 606
# the value of cost function is [[0.6724547]] in iteration # 607
# the value of cost function is [[0.67243786]] in iteration # 608
# the value of cost function is [[0.67242102]] in iteration # 609
# the value of cost function is [[0.6724042]] in iteration # 610
# the value of cost function is [[0.6723874]] in iteration # 611
# the value of cost function is [[0.6723706]] in iteration # 612
# the value of cost function is [[0.67235381]] in iteration # 613
# the value of cost function is [[0.67233704]] in iteration # 614
# the value of cost function is [[0.67232028]] in iteration # 615
# the value of cost function is [[0.67230353]] in iteration # 616
# the value of cost function is [[0.67228679]] in iteration # 617
# the value of cost function is [[0.67227006]] in iteration # 618
# the value of cost function is [[0.67225334]] in iteration # 619
# the value of cost function is [[0.67223664]] in iteration # 620
# the value of cost function is [[0.67221995]] in iteration # 621
# the value of cost function is [[0.67220326]] in iteration # 622
# the value of cost function is [[0.67218659]] in iteration # 623
# the value of cost function is [[0.67216993]] in iteration # 624
# the value of cost function is [[0.67215329]] in iteration # 625
# the value of cost function is [[0.67213665]] in iteration # 626
# the value of cost function is [[0.67212002]] in iteration # 627
# the value of cost function is [[0.67210341]] in iteration # 628
# the value of cost function is [[0.6720868]] in iteration # 629
# the value of cost function is [[0.67207021]] in iteration # 630
# the value of cost function is [[0.67205363]] in iteration # 631
# the value of cost function is [[0.67203706]] in iteration # 632
# the value of cost function is [[0.6720205]] in iteration # 633
# the value of cost function is [[0.67200395]] in iteration # 634
# the value of cost function is [[0.67198741]] in iteration # 635
# the value of cost function is [[0.67197088]] in iteration # 636
# the value of cost function is [[0.67195436]] in iteration # 637
# the value of cost function is [[0.67193786]] in iteration # 638
# the value of cost function is [[0.67192136]] in iteration # 639
# the value of cost function is [[0.67190487]] in iteration # 640
# the value of cost function is [[0.6718884]] in iteration # 641
# the value of cost function is [[0.67187193]] in iteration # 642
# the value of cost function is [[0.67185548]] in iteration # 643
# the value of cost function is [[0.67183904]] in iteration # 644
# the value of cost function is [[0.6718226]] in iteration # 645
# the value of cost function is [[0.67180618]] in iteration # 646
# the value of cost function is [[0.67178977]] in iteration # 647
# the value of cost function is [[0.67177337]] in iteration # 648
# the value of cost function is [[0.67175697]] in iteration # 649
# the value of cost function is [[0.67174059]] in iteration # 650
# the value of cost function is [[0.67172422]] in iteration # 651
# the value of cost function is [[0.67170786]] in iteration # 652
# the value of cost function is [[0.67169151]] in iteration # 653
# the value of cost function is [[0.67167517]] in iteration # 654
# the value of cost function is [[0.67165883]] in iteration # 655
# the value of cost function is [[0.67164251]] in iteration # 656
# the value of cost function is [[0.6716262]] in iteration # 657
# the value of cost function is [[0.6716099]] in iteration # 658
# the value of cost function is [[0.67159361]] in iteration # 659
# the value of cost function is [[0.67157733]] in iteration # 660
# the value of cost function is [[0.67156106]] in iteration # 661
# the value of cost function is [[0.67154479]] in iteration # 662
# the value of cost function is [[0.67152854]] in iteration # 663
# the value of cost function is [[0.6715123]] in iteration # 664
# the value of cost function is [[0.67149607]] in iteration # 665
# the value of cost function is [[0.67147984]] in iteration # 666
# the value of cost function is [[0.67146363]] in iteration # 667
# the value of cost function is [[0.67144742]] in iteration # 668
# the value of cost function is [[0.67143123]] in iteration # 669
# the value of cost function is [[0.67141505]] in iteration # 670
# the value of cost function is [[0.67139887]] in iteration # 671
# the value of cost function is [[0.6713827]] in iteration # 672
# the value of cost function is [[0.67136655]] in iteration # 673
# the value of cost function is [[0.6713504]] in iteration # 674
# the value of cost function is [[0.67133426]] in iteration # 675
# the value of cost function is [[0.67131814]] in iteration # 676
# the value of cost function is [[0.67130202]] in iteration # 677
# the value of cost function is [[0.67128591]] in iteration # 678
# the value of cost function is [[0.67126981]] in iteration # 679
# the value of cost function is [[0.67125372]] in iteration # 680
# the value of cost function is [[0.67123763]] in iteration # 681
# the value of cost function is [[0.67122156]] in iteration # 682
# the value of cost function is [[0.6712055]] in iteration # 683
# the value of cost function is [[0.67118944]] in iteration # 684
# the value of cost function is [[0.6711734]] in iteration # 685
# the value of cost function is [[0.67115736]] in iteration # 686
# the value of cost function is [[0.67114133]] in iteration # 687
# the value of cost function is [[0.67112532]] in iteration # 688
# the value of cost function is [[0.67110931]] in iteration # 689
# the value of cost function is [[0.67109331]] in iteration # 690
# the value of cost function is [[0.67107732]] in iteration # 691
# the value of cost function is [[0.67106133]] in iteration # 692
# the value of cost function is [[0.67104536]] in iteration # 693
# the value of cost function is [[0.6710294]] in iteration # 694
# the value of cost function is [[0.67101344]] in iteration # 695
# the value of cost function is [[0.67099749]] in iteration # 696
# the value of cost function is [[0.67098155]] in iteration # 697
# the value of cost function is [[0.67096562]] in iteration # 698
# the value of cost function is [[0.6709497]] in iteration # 699
# The cost after training is 0.67094970.
# The resulting vector of weights is [4.1e-07, 0.00035658, 7.309e-05]

# %% [markdown]
# #### Expected output
# ```
# The cost after training is 0.67094970.
# The resulting vector of weights is [4.1e-07, 0.00035658, 7.309e-05]
# ```

# %% [markdown]
# ## Part 2: Extracting the features
#
# * Given a list of tweets, extract the features and store them in a matrix. You will extract two features.
#     * The first feature is the number of positive words in a tweet.
#     * The second feature is the number of negative words in a tweet.
# * Then train your logistic regression classifier on these features.
# * Test the classifier on a validation set.
#
# ### Instructions: Implement the extract_features function.
# * This function takes in a single tweet.
# * Process the tweet using the imported `process_tweet()` function and save the list of tweet words.
# * Loop through each word in the list of processed words
#     * For each word, check the `freqs` dictionary for the count when that word has a positive '1' label. (Check for the key (word, 1.0)
#     * Do the same for the count for when the word is associated with the negative label '0'. (Check for the key (word, 0.0).)

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li>Make sure you handle cases when the (word, label) key is not found in the dictionary. </li>
#     <li> Search the web for hints about using the `.get()` method of a Python dictionary.  Here is an <a href="https://www.programiz.com/python-programming/methods/dictionary/get" > example </a> </li>
# </ul>
# </p>

# %%
# UNQ_C3 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def extract_features(tweet, freqs):
    '''
    Input: 
        tweet: a list of words for one tweet
        freqs: a dictionary corresponding to the frequencies of each tuple (word, label)
    Output: 
        x: a feature vector of dimension (1,3)
    '''
    # process_tweet tokenizes, stems, and removes stopwords
    word_l = process_tweet(tweet)
    
    # 3 elements in the form of a 1 x 3 vector
    x = np.zeros((1, 3)) 
    
    #bias term is set to 1
    x[0,0] = 1 
    
    ### START CODE HERE (REPLACE INSTANCES OF 'None' with your code) ###
    
    # loop through each word in the list of words
    for word in word_l:
        
        # increment the word count for the positive label 1
        x[0,1] += freqs.get((word,1),0)
        
        # increment the word count for the negative label 0
        x[0,2] += freqs.get((word,0),0)
        
    ### END CODE HERE ###
    assert(x.shape == (1, 3))
    return x

# %%
# Check your function

# test 1
# test on training data
tmp1 = extract_features(train_x[0], freqs)
print(tmp1)
# print(freqs.get(('followfriday',1)))
# train_x[0]

#output:
# [bias, sum(words appearing in positive labeled tweets), sum(words appearing in negative labelled tweets)]
# Out:
# [[1.00e+00 3.02e+03 6.10e+01]]

# %% [markdown]
# #### Expected output
# ```
# [[1.00e+00 3.02e+03 6.10e+01]]
# ```

# %%
# test 2:
# check for when the words are not in the freqs dictionary
tmp2 = extract_features('blorb bleeeeb bloooob', freqs)
print(tmp2)
# Out:
# [[1. 0. 0.]]

# %% [markdown]
# #### Expected output
# ```
# [[1. 0. 0.]]
# ```

# %% [markdown]
# ## Part 3: Training Your Model
#
# To train the model:
# * Stack the features for all training examples into a matrix `X`.
# * Call `gradientDescent`, which you've implemented above.
#
# This section is given to you.  Please read it for understanding and run the cell.

# %%
# collect the features 'x' and stack them into a matrix 'X'
X = np.zeros((len(train_x), 3))
for i in range(len(train_x)):
    X[i, :]= extract_features(train_x[i], freqs)

# training labels corresponding to X
Y = train_y

# Apply gradient descent
J, theta = gradientDescent(X, Y, np.zeros((3, 1)), 1e-9, 1500)
print(f"The cost after training is {J:.8f}.")
print(f"The resulting vector of weights is {[round(t, 8) for t in np.squeeze(theta)]}")
# Out:
# the value of cost function is [[0.69314718]] in iteration # 0
# the value of cost function is [[0.69207586]] in iteration # 1
# the value of cost function is [[0.69100783]] in iteration # 2
# the value of cost function is [[0.68994309]] in iteration # 3
# the value of cost function is [[0.68888162]] in iteration # 4
# the value of cost function is [[0.6878234]] in iteration # 5
# the value of cost function is [[0.68676844]] in iteration # 6
# the value of cost function is [[0.68571671]] in iteration # 7
# the value of cost function is [[0.6846682]] in iteration # 8
# the value of cost function is [[0.68362291]] in iteration # 9
# the value of cost function is [[0.68258083]] in iteration # 10
# the value of cost function is [[0.68154193]] in iteration # 11
# the value of cost function is [[0.68050622]] in iteration # 12
# the value of cost function is [[0.67947368]] in iteration # 13
# the value of cost function is [[0.67844429]] in iteration # 14
# the value of cost function is [[0.67741806]] in iteration # 15
# the value of cost function is [[0.67639496]] in iteration # 16
# the value of cost function is [[0.67537498]] in iteration # 17
# the value of cost function is [[0.67435812]] in iteration # 18
# the value of cost function is [[0.67334436]] in iteration # 19
# the value of cost function is [[0.67233369]] in iteration # 20
# the value of cost function is [[0.6713261]] in iteration # 21
# the value of cost function is [[0.67032159]] in iteration # 22
# the value of cost function is [[0.66932013]] in iteration # 23
# the value of cost function is [[0.66832171]] in iteration # 24
# the value of cost function is [[0.66732634]] in iteration # 25
# the value of cost function is [[0.66633399]] in iteration # 26
# the value of cost function is [[0.66534465]] in iteration # 27
# the value of cost function is [[0.66435832]] in iteration # 28
# the value of cost function is [[0.66337497]] in iteration # 29
# the value of cost function is [[0.66239461]] in iteration # 30
# the value of cost function is [[0.66141722]] in iteration # 31
# the value of cost function is [[0.66044279]] in iteration # 32
# the value of cost function is [[0.65947131]] in iteration # 33
# the value of cost function is [[0.65850276]] in iteration # 34
# the value of cost function is [[0.65753714]] in iteration # 35
# the value of cost function is [[0.65657444]] in iteration # 36
# the value of cost function is [[0.65561464]] in iteration # 37
# the value of cost function is [[0.65465774]] in iteration # 38
# the value of cost function is [[0.65370372]] in iteration # 39
# the value of cost function is [[0.65275257]] in iteration # 40
# the value of cost function is [[0.65180428]] in iteration # 41
# the value of cost function is [[0.65085885]] in iteration # 42
# the value of cost function is [[0.64991625]] in iteration # 43
# the value of cost function is [[0.64897649]] in iteration # 44
# the value of cost function is [[0.64803954]] in iteration # 45
# the value of cost function is [[0.6471054]] in iteration # 46
# the value of cost function is [[0.64617406]] in iteration # 47
# the value of cost function is [[0.64524551]] in iteration # 48
# the value of cost function is [[0.64431974]] in iteration # 49
# the value of cost function is [[0.64339673]] in iteration # 50
# the value of cost function is [[0.64247647]] in iteration # 51
# the value of cost function is [[0.64155897]] in iteration # 52
# the value of cost function is [[0.64064419]] in iteration # 53
# the value of cost function is [[0.63973214]] in iteration # 54
# the value of cost function is [[0.63882281]] in iteration # 55
# the value of cost function is [[0.63791618]] in iteration # 56
# the value of cost function is [[0.63701224]] in iteration # 57
# the value of cost function is [[0.63611099]] in iteration # 58
# the value of cost function is [[0.63521241]] in iteration # 59
# the value of cost function is [[0.63431649]] in iteration # 60
# the value of cost function is [[0.63342323]] in iteration # 61
# the value of cost function is [[0.6325326]] in iteration # 62
# the value of cost function is [[0.63164461]] in iteration # 63
# the value of cost function is [[0.63075925]] in iteration # 64
# the value of cost function is [[0.62987649]] in iteration # 65
# the value of cost function is [[0.62899634]] in iteration # 66
# the value of cost function is [[0.62811877]] in iteration # 67
# the value of cost function is [[0.62724379]] in iteration # 68
# the value of cost function is [[0.62637139]] in iteration # 69
# the value of cost function is [[0.62550154]] in iteration # 70
# the value of cost function is [[0.62463425]] in iteration # 71
# the value of cost function is [[0.6237695]] in iteration # 72
# the value of cost function is [[0.62290728]] in iteration # 73
# the value of cost function is [[0.62204759]] in iteration # 74
# the value of cost function is [[0.62119041]] in iteration # 75
# the value of cost function is [[0.62033573]] in iteration # 76
# the value of cost function is [[0.61948355]] in iteration # 77
# the value of cost function is [[0.61863385]] in iteration # 78
# the value of cost function is [[0.61778663]] in iteration # 79
# the value of cost function is [[0.61694187]] in iteration # 80
# the value of cost function is [[0.61609957]] in iteration # 81
# the value of cost function is [[0.61525971]] in iteration # 82
# the value of cost function is [[0.61442229]] in iteration # 83
# the value of cost function is [[0.61358729]] in iteration # 84
# the value of cost function is [[0.61275472]] in iteration # 85
# the value of cost function is [[0.61192455]] in iteration # 86
# the value of cost function is [[0.61109679]] in iteration # 87
# the value of cost function is [[0.61027141]] in iteration # 88
# the value of cost function is [[0.60944841]] in iteration # 89
# the value of cost function is [[0.60862779]] in iteration # 90
# the value of cost function is [[0.60780952]] in iteration # 91
# the value of cost function is [[0.60699361]] in iteration # 92
# the value of cost function is [[0.60618005]] in iteration # 93
# the value of cost function is [[0.60536881]] in iteration # 94
# the value of cost function is [[0.60455991]] in iteration # 95
# the value of cost function is [[0.60375332]] in iteration # 96
# the value of cost function is [[0.60294904]] in iteration # 97
# the value of cost function is [[0.60214706]] in iteration # 98
# the value of cost function is [[0.60134737]] in iteration # 99
# the value of cost function is [[0.60054995]] in iteration # 100
# the value of cost function is [[0.59975482]] in iteration # 101
# the value of cost function is [[0.59896194]] in iteration # 102
# the value of cost function is [[0.59817132]] in iteration # 103
# the value of cost function is [[0.59738295]] in iteration # 104
# the value of cost function is [[0.59659681]] in iteration # 105
# the value of cost function is [[0.5958129]] in iteration # 106
# the value of cost function is [[0.59503122]] in iteration # 107
# the value of cost function is [[0.59425174]] in iteration # 108
# the value of cost function is [[0.59347447]] in iteration # 109
# the value of cost function is [[0.59269939]] in iteration # 110
# the value of cost function is [[0.5919265]] in iteration # 111
# the value of cost function is [[0.59115578]] in iteration # 112
# the value of cost function is [[0.59038724]] in iteration # 113
# the value of cost function is [[0.58962085]] in iteration # 114
# the value of cost function is [[0.58885662]] in iteration # 115
# the value of cost function is [[0.58809453]] in iteration # 116
# the value of cost function is [[0.58733458]] in iteration # 117
# the value of cost function is [[0.58657676]] in iteration # 118
# the value of cost function is [[0.58582105]] in iteration # 119
# the value of cost function is [[0.58506746]] in iteration # 120
# the value of cost function is [[0.58431597]] in iteration # 121
# the value of cost function is [[0.58356657]] in iteration # 122
# the value of cost function is [[0.58281927]] in iteration # 123
# the value of cost function is [[0.58207404]] in iteration # 124
# the value of cost function is [[0.58133088]] in iteration # 125
# the value of cost function is [[0.58058978]] in iteration # 126
# the value of cost function is [[0.57985074]] in iteration # 127
# the value of cost function is [[0.57911375]] in iteration # 128
# the value of cost function is [[0.5783788]] in iteration # 129
# the value of cost function is [[0.57764588]] in iteration # 130
# the value of cost function is [[0.57691498]] in iteration # 131
# the value of cost function is [[0.5761861]] in iteration # 132
# the value of cost function is [[0.57545923]] in iteration # 133
# the value of cost function is [[0.57473436]] in iteration # 134
# the value of cost function is [[0.57401148]] in iteration # 135
# the value of cost function is [[0.57329059]] in iteration # 136
# the value of cost function is [[0.57257167]] in iteration # 137
# the value of cost function is [[0.57185473]] in iteration # 138
# the value of cost function is [[0.57113974]] in iteration # 139
# the value of cost function is [[0.57042672]] in iteration # 140
# the value of cost function is [[0.56971564]] in iteration # 141
# the value of cost function is [[0.5690065]] in iteration # 142
# the value of cost function is [[0.5682993]] in iteration # 143
# the value of cost function is [[0.56759402]] in iteration # 144
# the value of cost function is [[0.56689066]] in iteration # 145
# the value of cost function is [[0.56618921]] in iteration # 146
# the value of cost function is [[0.56548967]] in iteration # 147
# the value of cost function is [[0.56479202]] in iteration # 148
# the value of cost function is [[0.56409626]] in iteration # 149
# the value of cost function is [[0.56340238]] in iteration # 150
# the value of cost function is [[0.56271038]] in iteration # 151
# the value of cost function is [[0.56202025]] in iteration # 152
# the value of cost function is [[0.56133198]] in iteration # 153
# the value of cost function is [[0.56064556]] in iteration # 154
# the value of cost function is [[0.55996099]] in iteration # 155
# the value of cost function is [[0.55927826]] in iteration # 156
# the value of cost function is [[0.55859736]] in iteration # 157
# the value of cost function is [[0.55791829]] in iteration # 158
# the value of cost function is [[0.55724104]] in iteration # 159
# the value of cost function is [[0.55656561]] in iteration # 160
# the value of cost function is [[0.55589197]] in iteration # 161
# the value of cost function is [[0.55522014]] in iteration # 162
# the value of cost function is [[0.5545501]] in iteration # 163
# the value of cost function is [[0.55388184]] in iteration # 164
# the value of cost function is [[0.55321537]] in iteration # 165
# the value of cost function is [[0.55255066]] in iteration # 166
# the value of cost function is [[0.55188773]] in iteration # 167
# the value of cost function is [[0.55122655]] in iteration # 168
# the value of cost function is [[0.55056712]] in iteration # 169
# the value of cost function is [[0.54990944]] in iteration # 170
# the value of cost function is [[0.5492535]] in iteration # 171
# the value of cost function is [[0.54859929]] in iteration # 172
# the value of cost function is [[0.54794681]] in iteration # 173
# the value of cost function is [[0.54729605]] in iteration # 174
# the value of cost function is [[0.546647]] in iteration # 175
# the value of cost function is [[0.54599966]] in iteration # 176
# the value of cost function is [[0.54535402]] in iteration # 177
# the value of cost function is [[0.54471007]] in iteration # 178
# the value of cost function is [[0.54406782]] in iteration # 179
# the value of cost function is [[0.54342724]] in iteration # 180
# the value of cost function is [[0.54278835]] in iteration # 181
# the value of cost function is [[0.54215112]] in iteration # 182
# the value of cost function is [[0.54151555]] in iteration # 183
# the value of cost function is [[0.54088164]] in iteration # 184
# the value of cost function is [[0.54024939]] in iteration # 185
# the value of cost function is [[0.53961878]] in iteration # 186
# the value of cost function is [[0.53898981]] in iteration # 187
# the value of cost function is [[0.53836247]] in iteration # 188
# the value of cost function is [[0.53773676]] in iteration # 189
# the value of cost function is [[0.53711267]] in iteration # 190
# the value of cost function is [[0.53649019]] in iteration # 191
# the value of cost function is [[0.53586933]] in iteration # 192
# the value of cost function is [[0.53525007]] in iteration # 193
# the value of cost function is [[0.5346324]] in iteration # 194
# the value of cost function is [[0.53401633]] in iteration # 195
# the value of cost function is [[0.53340185]] in iteration # 196
# the value of cost function is [[0.53278894]] in iteration # 197
# the value of cost function is [[0.53217761]] in iteration # 198
# the value of cost function is [[0.53156785]] in iteration # 199
# the value of cost function is [[0.53095965]] in iteration # 200
# the value of cost function is [[0.530353]] in iteration # 201
# the value of cost function is [[0.52974791]] in iteration # 202
# the value of cost function is [[0.52914437]] in iteration # 203
# the value of cost function is [[0.52854237]] in iteration # 204
# the value of cost function is [[0.5279419]] in iteration # 205
# the value of cost function is [[0.52734296]] in iteration # 206
# the value of cost function is [[0.52674554]] in iteration # 207
# the value of cost function is [[0.52614964]] in iteration # 208
# the value of cost function is [[0.52555526]] in iteration # 209
# the value of cost function is [[0.52496238]] in iteration # 210
# the value of cost function is [[0.524371]] in iteration # 211
# the value of cost function is [[0.52378112]] in iteration # 212
# the value of cost function is [[0.52319274]] in iteration # 213
# the value of cost function is [[0.52260583]] in iteration # 214
# the value of cost function is [[0.52202041]] in iteration # 215
# the value of cost function is [[0.52143647]] in iteration # 216
# the value of cost function is [[0.52085399]] in iteration # 217
# the value of cost function is [[0.52027298]] in iteration # 218
# the value of cost function is [[0.51969342]] in iteration # 219
# the value of cost function is [[0.51911533]] in iteration # 220
# the value of cost function is [[0.51853868]] in iteration # 221
# the value of cost function is [[0.51796347]] in iteration # 222
# the value of cost function is [[0.5173897]] in iteration # 223
# the value of cost function is [[0.51681737]] in iteration # 224
# the value of cost function is [[0.51624646]] in iteration # 225
# the value of cost function is [[0.51567698]] in iteration # 226
# the value of cost function is [[0.51510892]] in iteration # 227
# the value of cost function is [[0.51454227]] in iteration # 228
# the value of cost function is [[0.51397702]] in iteration # 229
# the value of cost function is [[0.51341318]] in iteration # 230
# the value of cost function is [[0.51285074]] in iteration # 231
# the value of cost function is [[0.5122897]] in iteration # 232
# the value of cost function is [[0.51173004]] in iteration # 233
# the value of cost function is [[0.51117176]] in iteration # 234
# the value of cost function is [[0.51061486]] in iteration # 235
# the value of cost function is [[0.51005934]] in iteration # 236
# the value of cost function is [[0.50950519]] in iteration # 237
# the value of cost function is [[0.5089524]] in iteration # 238
# the value of cost function is [[0.50840097]] in iteration # 239
# the value of cost function is [[0.50785089]] in iteration # 240
# the value of cost function is [[0.50730217]] in iteration # 241
# the value of cost function is [[0.50675478]] in iteration # 242
# the value of cost function is [[0.50620874]] in iteration # 243
# the value of cost function is [[0.50566404]] in iteration # 244
# the value of cost function is [[0.50512067]] in iteration # 245
# the value of cost function is [[0.50457862]] in iteration # 246
# the value of cost function is [[0.50403789]] in iteration # 247
# the value of cost function is [[0.50349848]] in iteration # 248
# the value of cost function is [[0.50296039]] in iteration # 249
# the value of cost function is [[0.5024236]] in iteration # 250
# the value of cost function is [[0.50188812]] in iteration # 251
# the value of cost function is [[0.50135393]] in iteration # 252
# the value of cost function is [[0.50082104]] in iteration # 253
# the value of cost function is [[0.50028944]] in iteration # 254
# the value of cost function is [[0.49975913]] in iteration # 255
# the value of cost function is [[0.49923009]] in iteration # 256
# the value of cost function is [[0.49870233]] in iteration # 257
# the value of cost function is [[0.49817585]] in iteration # 258
# the value of cost function is [[0.49765063]] in iteration # 259
# the value of cost function is [[0.49712668]] in iteration # 260
# the value of cost function is [[0.49660398]] in iteration # 261
# the value of cost function is [[0.49608254]] in iteration # 262
# the value of cost function is [[0.49556236]] in iteration # 263
# the value of cost function is [[0.49504341]] in iteration # 264
# the value of cost function is [[0.49452571]] in iteration # 265
# the value of cost function is [[0.49400925]] in iteration # 266
# the value of cost function is [[0.49349402]] in iteration # 267
# the value of cost function is [[0.49298002]] in iteration # 268
# the value of cost function is [[0.49246724]] in iteration # 269
# the value of cost function is [[0.49195569]] in iteration # 270
# the value of cost function is [[0.49144535]] in iteration # 271
# the value of cost function is [[0.49093623]] in iteration # 272
# the value of cost function is [[0.49042831]] in iteration # 273
# the value of cost function is [[0.4899216]] in iteration # 274
# the value of cost function is [[0.48941609]] in iteration # 275
# the value of cost function is [[0.48891177]] in iteration # 276
# the value of cost function is [[0.48840865]] in iteration # 277
# the value of cost function is [[0.48790671]] in iteration # 278
# the value of cost function is [[0.48740596]] in iteration # 279
# the value of cost function is [[0.48690639]] in iteration # 280
# the value of cost function is [[0.486408]] in iteration # 281
# the value of cost function is [[0.48591077]] in iteration # 282
# the value of cost function is [[0.48541472]] in iteration # 283
# the value of cost function is [[0.48491983]] in iteration # 284
# the value of cost function is [[0.4844261]] in iteration # 285
# the value of cost function is [[0.48393352]] in iteration # 286
# the value of cost function is [[0.4834421]] in iteration # 287
# the value of cost function is [[0.48295183]] in iteration # 288
# the value of cost function is [[0.4824627]] in iteration # 289
# the value of cost function is [[0.48197472]] in iteration # 290
# the value of cost function is [[0.48148787]] in iteration # 291
# the value of cost function is [[0.48100215]] in iteration # 292
# the value of cost function is [[0.48051757]] in iteration # 293
# the value of cost function is [[0.48003411]] in iteration # 294
# the value of cost function is [[0.47955177]] in iteration # 295
# the value of cost function is [[0.47907055]] in iteration # 296
# the value of cost function is [[0.47859044]] in iteration # 297
# the value of cost function is [[0.47811145]] in iteration # 298
# the value of cost function is [[0.47763356]] in iteration # 299
# the value of cost function is [[0.47715678]] in iteration # 300
# the value of cost function is [[0.4766811]] in iteration # 301
# the value of cost function is [[0.47620651]] in iteration # 302
# the value of cost function is [[0.47573302]] in iteration # 303
# the value of cost function is [[0.47526061]] in iteration # 304
# the value of cost function is [[0.47478929]] in iteration # 305
# the value of cost function is [[0.47431905]] in iteration # 306
# the value of cost function is [[0.47384989]] in iteration # 307
# the value of cost function is [[0.47338181]] in iteration # 308
# the value of cost function is [[0.4729148]] in iteration # 309
# the value of cost function is [[0.47244885]] in iteration # 310
# the value of cost function is [[0.47198397]] in iteration # 311
# the value of cost function is [[0.47152015]] in iteration # 312
# the value of cost function is [[0.47105739]] in iteration # 313
# the value of cost function is [[0.47059568]] in iteration # 314
# the value of cost function is [[0.47013502]] in iteration # 315
# the value of cost function is [[0.4696754]] in iteration # 316
# the value of cost function is [[0.46921684]] in iteration # 317
# the value of cost function is [[0.46875931]] in iteration # 318
# the value of cost function is [[0.46830282]] in iteration # 319
# the value of cost function is [[0.46784736]] in iteration # 320
# the value of cost function is [[0.46739293]] in iteration # 321
# the value of cost function is [[0.46693953]] in iteration # 322
# the value of cost function is [[0.46648715]] in iteration # 323
# the value of cost function is [[0.46603579]] in iteration # 324
# the value of cost function is [[0.46558545]] in iteration # 325
# the value of cost function is [[0.46513612]] in iteration # 326
# the value of cost function is [[0.4646878]] in iteration # 327
# the value of cost function is [[0.46424049]] in iteration # 328
# the value of cost function is [[0.46379418]] in iteration # 329
# the value of cost function is [[0.46334887]] in iteration # 330
# the value of cost function is [[0.46290456]] in iteration # 331
# the value of cost function is [[0.46246125]] in iteration # 332
# the value of cost function is [[0.46201892]] in iteration # 333
# the value of cost function is [[0.46157758]] in iteration # 334
# the value of cost function is [[0.46113723]] in iteration # 335
# the value of cost function is [[0.46069786]] in iteration # 336
# the value of cost function is [[0.46025946]] in iteration # 337
# the value of cost function is [[0.45982204]] in iteration # 338
# the value of cost function is [[0.4593856]] in iteration # 339
# the value of cost function is [[0.45895012]] in iteration # 340
# the value of cost function is [[0.4585156]] in iteration # 341
# the value of cost function is [[0.45808205]] in iteration # 342
# the value of cost function is [[0.45764946]] in iteration # 343
# the value of cost function is [[0.45721783]] in iteration # 344
# the value of cost function is [[0.45678715]] in iteration # 345
# the value of cost function is [[0.45635742]] in iteration # 346
# the value of cost function is [[0.45592863]] in iteration # 347
# the value of cost function is [[0.4555008]] in iteration # 348
# the value of cost function is [[0.4550739]] in iteration # 349
# the value of cost function is [[0.45464794]] in iteration # 350
# the value of cost function is [[0.45422292]] in iteration # 351
# the value of cost function is [[0.45379882]] in iteration # 352
# the value of cost function is [[0.45337566]] in iteration # 353
# the value of cost function is [[0.45295343]] in iteration # 354
# the value of cost function is [[0.45253212]] in iteration # 355
# the value of cost function is [[0.45211173]] in iteration # 356
# the value of cost function is [[0.45169225]] in iteration # 357
# the value of cost function is [[0.4512737]] in iteration # 358
# the value of cost function is [[0.45085605]] in iteration # 359
# the value of cost function is [[0.45043931]] in iteration # 360
# the value of cost function is [[0.45002348]] in iteration # 361
# the value of cost function is [[0.44960856]] in iteration # 362
# the value of cost function is [[0.44919453]] in iteration # 363
# the value of cost function is [[0.44878141]] in iteration # 364
# the value of cost function is [[0.44836917]] in iteration # 365
# the value of cost function is [[0.44795783]] in iteration # 366
# the value of cost function is [[0.44754738]] in iteration # 367
# the value of cost function is [[0.44713782]] in iteration # 368
# the value of cost function is [[0.44672914]] in iteration # 369
# the value of cost function is [[0.44632134]] in iteration # 370
# the value of cost function is [[0.44591442]] in iteration # 371
# the value of cost function is [[0.44550838]] in iteration # 372
# the value of cost function is [[0.44510321]] in iteration # 373
# the value of cost function is [[0.44469891]] in iteration # 374
# the value of cost function is [[0.44429548]] in iteration # 375
# the value of cost function is [[0.44389291]] in iteration # 376
# the value of cost function is [[0.44349121]] in iteration # 377
# the value of cost function is [[0.44309036]] in iteration # 378
# the value of cost function is [[0.44269037]] in iteration # 379
# the value of cost function is [[0.44229124]] in iteration # 380
# the value of cost function is [[0.44189296]] in iteration # 381
# the value of cost function is [[0.44149553]] in iteration # 382
# the value of cost function is [[0.44109894]] in iteration # 383
# the value of cost function is [[0.4407032]] in iteration # 384
# the value of cost function is [[0.4403083]] in iteration # 385
# the value of cost function is [[0.43991424]] in iteration # 386
# the value of cost function is [[0.43952101]] in iteration # 387
# the value of cost function is [[0.43912862]] in iteration # 388
# the value of cost function is [[0.43873706]] in iteration # 389
# the value of cost function is [[0.43834633]] in iteration # 390
# the value of cost function is [[0.43795642]] in iteration # 391
# the value of cost function is [[0.43756734]] in iteration # 392
# the value of cost function is [[0.43717908]] in iteration # 393
# the value of cost function is [[0.43679164]] in iteration # 394
# the value of cost function is [[0.43640501]] in iteration # 395
# the value of cost function is [[0.4360192]] in iteration # 396
# the value of cost function is [[0.4356342]] in iteration # 397
# the value of cost function is [[0.43525001]] in iteration # 398
# the value of cost function is [[0.43486662]] in iteration # 399
# the value of cost function is [[0.43448404]] in iteration # 400
# the value of cost function is [[0.43410226]] in iteration # 401
# the value of cost function is [[0.43372127]] in iteration # 402
# the value of cost function is [[0.43334109]] in iteration # 403
# the value of cost function is [[0.4329617]] in iteration # 404
# the value of cost function is [[0.4325831]] in iteration # 405
# the value of cost function is [[0.43220529]] in iteration # 406
# the value of cost function is [[0.43182826]] in iteration # 407
# the value of cost function is [[0.43145203]] in iteration # 408
# the value of cost function is [[0.43107657]] in iteration # 409
# the value of cost function is [[0.43070189]] in iteration # 410
# the value of cost function is [[0.43032799]] in iteration # 411
# the value of cost function is [[0.42995487]] in iteration # 412
# the value of cost function is [[0.42958252]] in iteration # 413
# the value of cost function is [[0.42921094]] in iteration # 414
# the value of cost function is [[0.42884013]] in iteration # 415
# the value of cost function is [[0.42847009]] in iteration # 416
# the value of cost function is [[0.4281008]] in iteration # 417
# the value of cost function is [[0.42773229]] in iteration # 418
# the value of cost function is [[0.42736453]] in iteration # 419
# the value of cost function is [[0.42699752]] in iteration # 420
# the value of cost function is [[0.42663127]] in iteration # 421
# the value of cost function is [[0.42626578]] in iteration # 422
# the value of cost function is [[0.42590103]] in iteration # 423
# the value of cost function is [[0.42553703]] in iteration # 424
# the value of cost function is [[0.42517378]] in iteration # 425
# the value of cost function is [[0.42481128]] in iteration # 426
# the value of cost function is [[0.42444951]] in iteration # 427
# the value of cost function is [[0.42408848]] in iteration # 428
# the value of cost function is [[0.42372819]] in iteration # 429
# the value of cost function is [[0.42336864]] in iteration # 430
# the value of cost function is [[0.42300981]] in iteration # 431
# the value of cost function is [[0.42265172]] in iteration # 432
# the value of cost function is [[0.42229436]] in iteration # 433
# the value of cost function is [[0.42193772]] in iteration # 434
# the value of cost function is [[0.42158181]] in iteration # 435
# the value of cost function is [[0.42122662]] in iteration # 436
# the value of cost function is [[0.42087215]] in iteration # 437
# the value of cost function is [[0.4205184]] in iteration # 438
# the value of cost function is [[0.42016536]] in iteration # 439
# the value of cost function is [[0.41981304]] in iteration # 440
# the value of cost function is [[0.41946143]] in iteration # 441
# the value of cost function is [[0.41911053]] in iteration # 442
# the value of cost function is [[0.41876033]] in iteration # 443
# the value of cost function is [[0.41841084]] in iteration # 444
# the value of cost function is [[0.41806206]] in iteration # 445
# the value of cost function is [[0.41771398]] in iteration # 446
# the value of cost function is [[0.41736659]] in iteration # 447
# the value of cost function is [[0.4170199]] in iteration # 448
# the value of cost function is [[0.41667391]] in iteration # 449
# the value of cost function is [[0.41632861]] in iteration # 450
# the value of cost function is [[0.41598401]] in iteration # 451
# the value of cost function is [[0.41564009]] in iteration # 452
# the value of cost function is [[0.41529686]] in iteration # 453
# the value of cost function is [[0.41495431]] in iteration # 454
# the value of cost function is [[0.41461245]] in iteration # 455
# the value of cost function is [[0.41427127]] in iteration # 456
# the value of cost function is [[0.41393077]] in iteration # 457
# the value of cost function is [[0.41359094]] in iteration # 458
# the value of cost function is [[0.41325179]] in iteration # 459
# the value of cost function is [[0.41291332]] in iteration # 460
# the value of cost function is [[0.41257552]] in iteration # 461
# the value of cost function is [[0.41223838]] in iteration # 462
# the value of cost function is [[0.41190192]] in iteration # 463
# the value of cost function is [[0.41156612]] in iteration # 464
# the value of cost function is [[0.41123098]] in iteration # 465
# the value of cost function is [[0.41089651]] in iteration # 466
# the value of cost function is [[0.41056269]] in iteration # 467
# the value of cost function is [[0.41022954]] in iteration # 468
# the value of cost function is [[0.40989704]] in iteration # 469
# the value of cost function is [[0.4095652]] in iteration # 470
# the value of cost function is [[0.409234]] in iteration # 471
# the value of cost function is [[0.40890346]] in iteration # 472
# the value of cost function is [[0.40857357]] in iteration # 473
# the value of cost function is [[0.40824433]] in iteration # 474
# the value of cost function is [[0.40791573]] in iteration # 475
# the value of cost function is [[0.40758777]] in iteration # 476
# the value of cost function is [[0.40726046]] in iteration # 477
# the value of cost function is [[0.40693379]] in iteration # 478
# the value of cost function is [[0.40660775]] in iteration # 479
# the value of cost function is [[0.40628235]] in iteration # 480
# the value of cost function is [[0.40595759]] in iteration # 481
# the value of cost function is [[0.40563346]] in iteration # 482
# the value of cost function is [[0.40530996]] in iteration # 483
# the value of cost function is [[0.40498708]] in iteration # 484
# the value of cost function is [[0.40466484]] in iteration # 485
# the value of cost function is [[0.40434322]] in iteration # 486
# the value of cost function is [[0.40402223]] in iteration # 487
# the value of cost function is [[0.40370185]] in iteration # 488
# the value of cost function is [[0.4033821]] in iteration # 489
# the value of cost function is [[0.40306297]] in iteration # 490
# the value of cost function is [[0.40274445]] in iteration # 491
# the value of cost function is [[0.40242655]] in iteration # 492
# the value of cost function is [[0.40210926]] in iteration # 493
# the value of cost function is [[0.40179259]] in iteration # 494
# the value of cost function is [[0.40147652]] in iteration # 495
# the value of cost function is [[0.40116106]] in iteration # 496
# the value of cost function is [[0.40084621]] in iteration # 497
# the value of cost function is [[0.40053197]] in iteration # 498
# the value of cost function is [[0.40021833]] in iteration # 499
# the value of cost function is [[0.39990529]] in iteration # 500
# the value of cost function is [[0.39959285]] in iteration # 501
# the value of cost function is [[0.399281]] in iteration # 502
# the value of cost function is [[0.39896976]] in iteration # 503
# the value of cost function is [[0.39865911]] in iteration # 504
# the value of cost function is [[0.39834905]] in iteration # 505
# the value of cost function is [[0.39803959]] in iteration # 506
# the value of cost function is [[0.39773071]] in iteration # 507
# the value of cost function is [[0.39742242]] in iteration # 508
# the value of cost function is [[0.39711473]] in iteration # 509
# the value of cost function is [[0.39680761]] in iteration # 510
# the value of cost function is [[0.39650108]] in iteration # 511
# the value of cost function is [[0.39619513]] in iteration # 512
# the value of cost function is [[0.39588976]] in iteration # 513
# the value of cost function is [[0.39558498]] in iteration # 514
# the value of cost function is [[0.39528076]] in iteration # 515
# the value of cost function is [[0.39497713]] in iteration # 516
# the value of cost function is [[0.39467407]] in iteration # 517
# the value of cost function is [[0.39437158]] in iteration # 518
# the value of cost function is [[0.39406966]] in iteration # 519
# the value of cost function is [[0.39376831]] in iteration # 520
# the value of cost function is [[0.39346753]] in iteration # 521
# the value of cost function is [[0.39316732]] in iteration # 522
# the value of cost function is [[0.39286767]] in iteration # 523
# the value of cost function is [[0.39256858]] in iteration # 524
# the value of cost function is [[0.39227006]] in iteration # 525
# the value of cost function is [[0.39197209]] in iteration # 526
# the value of cost function is [[0.39167469]] in iteration # 527
# the value of cost function is [[0.39137784]] in iteration # 528
# the value of cost function is [[0.39108155]] in iteration # 529
# the value of cost function is [[0.39078581]] in iteration # 530
# the value of cost function is [[0.39049063]] in iteration # 531
# the value of cost function is [[0.39019599]] in iteration # 532
# the value of cost function is [[0.38990191]] in iteration # 533
# the value of cost function is [[0.38960837]] in iteration # 534
# the value of cost function is [[0.38931538]] in iteration # 535
# the value of cost function is [[0.38902294]] in iteration # 536
# the value of cost function is [[0.38873104]] in iteration # 537
# the value of cost function is [[0.38843968]] in iteration # 538
# the value of cost function is [[0.38814887]] in iteration # 539
# the value of cost function is [[0.38785859]] in iteration # 540
# the value of cost function is [[0.38756885]] in iteration # 541
# the value of cost function is [[0.38727965]] in iteration # 542
# the value of cost function is [[0.38699098]] in iteration # 543
# the value of cost function is [[0.38670285]] in iteration # 544
# the value of cost function is [[0.38641525]] in iteration # 545
# the value of cost function is [[0.38612818]] in iteration # 546
# the value of cost function is [[0.38584164]] in iteration # 547
# the value of cost function is [[0.38555563]] in iteration # 548
# the value of cost function is [[0.38527014]] in iteration # 549
# the value of cost function is [[0.38498518]] in iteration # 550
# the value of cost function is [[0.38470074]] in iteration # 551
# the value of cost function is [[0.38441683]] in iteration # 552
# the value of cost function is [[0.38413344]] in iteration # 553
# the value of cost function is [[0.38385056]] in iteration # 554
# the value of cost function is [[0.38356821]] in iteration # 555
# the value of cost function is [[0.38328637]] in iteration # 556
# the value of cost function is [[0.38300505]] in iteration # 557
# the value of cost function is [[0.38272424]] in iteration # 558
# the value of cost function is [[0.38244394]] in iteration # 559
# the value of cost function is [[0.38216416]] in iteration # 560
# the value of cost function is [[0.38188489]] in iteration # 561
# the value of cost function is [[0.38160612]] in iteration # 562
# the value of cost function is [[0.38132787]] in iteration # 563
# the value of cost function is [[0.38105011]] in iteration # 564
# the value of cost function is [[0.38077287]] in iteration # 565
# the value of cost function is [[0.38049613]] in iteration # 566
# the value of cost function is [[0.38021989]] in iteration # 567
# the value of cost function is [[0.37994415]] in iteration # 568
# the value of cost function is [[0.37966891]] in iteration # 569
# the value of cost function is [[0.37939416]] in iteration # 570
# the value of cost function is [[0.37911992]] in iteration # 571
# the value of cost function is [[0.37884617]] in iteration # 572
# the value of cost function is [[0.37857292]] in iteration # 573
# the value of cost function is [[0.37830015]] in iteration # 574
# the value of cost function is [[0.37802788]] in iteration # 575
# the value of cost function is [[0.37775611]] in iteration # 576
# the value of cost function is [[0.37748482]] in iteration # 577
# the value of cost function is [[0.37721401]] in iteration # 578
# the value of cost function is [[0.3769437]] in iteration # 579
# the value of cost function is [[0.37667387]] in iteration # 580
# the value of cost function is [[0.37640452]] in iteration # 581
# the value of cost function is [[0.37613566]] in iteration # 582
# the value of cost function is [[0.37586728]] in iteration # 583
# the value of cost function is [[0.37559938]] in iteration # 584
# the value of cost function is [[0.37533196]] in iteration # 585
# the value of cost function is [[0.37506501]] in iteration # 586
# the value of cost function is [[0.37479854]] in iteration # 587
# the value of cost function is [[0.37453255]] in iteration # 588
# the value of cost function is [[0.37426704]] in iteration # 589
# the value of cost function is [[0.37400199]] in iteration # 590
# the value of cost function is [[0.37373742]] in iteration # 591
# the value of cost function is [[0.37347332]] in iteration # 592
# the value of cost function is [[0.37320968]] in iteration # 593
# the value of cost function is [[0.37294652]] in iteration # 594
# the value of cost function is [[0.37268382]] in iteration # 595
# the value of cost function is [[0.37242159]] in iteration # 596
# the value of cost function is [[0.37215982]] in iteration # 597
# the value of cost function is [[0.37189852]] in iteration # 598
# the value of cost function is [[0.37163768]] in iteration # 599
# the value of cost function is [[0.3713773]] in iteration # 600
# the value of cost function is [[0.37111738]] in iteration # 601
# the value of cost function is [[0.37085792]] in iteration # 602
# the value of cost function is [[0.37059891]] in iteration # 603
# the value of cost function is [[0.37034037]] in iteration # 604
# the value of cost function is [[0.37008227]] in iteration # 605
# the value of cost function is [[0.36982463]] in iteration # 606
# the value of cost function is [[0.36956745]] in iteration # 607
# the value of cost function is [[0.36931071]] in iteration # 608
# the value of cost function is [[0.36905443]] in iteration # 609
# the value of cost function is [[0.3687986]] in iteration # 610
# the value of cost function is [[0.36854321]] in iteration # 611
# the value of cost function is [[0.36828827]] in iteration # 612
# the value of cost function is [[0.36803378]] in iteration # 613
# the value of cost function is [[0.36777973]] in iteration # 614
# the value of cost function is [[0.36752613]] in iteration # 615
# the value of cost function is [[0.36727297]] in iteration # 616
# the value of cost function is [[0.36702025]] in iteration # 617
# the value of cost function is [[0.36676797]] in iteration # 618
# the value of cost function is [[0.36651613]] in iteration # 619
# the value of cost function is [[0.36626473]] in iteration # 620
# the value of cost function is [[0.36601376]] in iteration # 621
# the value of cost function is [[0.36576323]] in iteration # 622
# the value of cost function is [[0.36551314]] in iteration # 623
# the value of cost function is [[0.36526348]] in iteration # 624
# the value of cost function is [[0.36501425]] in iteration # 625
# the value of cost function is [[0.36476546]] in iteration # 626
# the value of cost function is [[0.36451709]] in iteration # 627
# the value of cost function is [[0.36426916]] in iteration # 628
# the value of cost function is [[0.36402165]] in iteration # 629
# the value of cost function is [[0.36377457]] in iteration # 630
# the value of cost function is [[0.36352792]] in iteration # 631
# the value of cost function is [[0.36328169]] in iteration # 632
# the value of cost function is [[0.36303589]] in iteration # 633
# the value of cost function is [[0.36279051]] in iteration # 634
# the value of cost function is [[0.36254555]] in iteration # 635
# the value of cost function is [[0.36230101]] in iteration # 636
# the value of cost function is [[0.36205689]] in iteration # 637
# the value of cost function is [[0.36181319]] in iteration # 638
# the value of cost function is [[0.36156991]] in iteration # 639
# the value of cost function is [[0.36132705]] in iteration # 640
# the value of cost function is [[0.3610846]] in iteration # 641
# the value of cost function is [[0.36084257]] in iteration # 642
# the value of cost function is [[0.36060095]] in iteration # 643
# the value of cost function is [[0.36035974]] in iteration # 644
# the value of cost function is [[0.36011894]] in iteration # 645
# the value of cost function is [[0.35987856]] in iteration # 646
# the value of cost function is [[0.35963858]] in iteration # 647
# the value of cost function is [[0.35939902]] in iteration # 648
# the value of cost function is [[0.35915986]] in iteration # 649
# the value of cost function is [[0.35892111]] in iteration # 650
# the value of cost function is [[0.35868276]] in iteration # 651
# the value of cost function is [[0.35844482]] in iteration # 652
# the value of cost function is [[0.35820728]] in iteration # 653
# the value of cost function is [[0.35797015]] in iteration # 654
# the value of cost function is [[0.35773341]] in iteration # 655
# the value of cost function is [[0.35749708]] in iteration # 656
# the value of cost function is [[0.35726115]] in iteration # 657
# the value of cost function is [[0.35702561]] in iteration # 658
# the value of cost function is [[0.35679048]] in iteration # 659
# the value of cost function is [[0.35655574]] in iteration # 660
# the value of cost function is [[0.35632139]] in iteration # 661
# the value of cost function is [[0.35608744]] in iteration # 662
# the value of cost function is [[0.35585389]] in iteration # 663
# the value of cost function is [[0.35562073]] in iteration # 664
# the value of cost function is [[0.35538796]] in iteration # 665
# the value of cost function is [[0.35515558]] in iteration # 666
# the value of cost function is [[0.35492359]] in iteration # 667
# the value of cost function is [[0.35469199]] in iteration # 668
# the value of cost function is [[0.35446078]] in iteration # 669
# the value of cost function is [[0.35422995]] in iteration # 670
# the value of cost function is [[0.35399951]] in iteration # 671
# the value of cost function is [[0.35376946]] in iteration # 672
# the value of cost function is [[0.35353979]] in iteration # 673
# the value of cost function is [[0.35331051]] in iteration # 674
# the value of cost function is [[0.35308161]] in iteration # 675
# the value of cost function is [[0.35285308]] in iteration # 676
# the value of cost function is [[0.35262495]] in iteration # 677
# the value of cost function is [[0.35239719]] in iteration # 678
# the value of cost function is [[0.3521698]] in iteration # 679
# the value of cost function is [[0.3519428]] in iteration # 680
# the value of cost function is [[0.35171618]] in iteration # 681
# the value of cost function is [[0.35148993]] in iteration # 682
# the value of cost function is [[0.35126405]] in iteration # 683
# the value of cost function is [[0.35103855]] in iteration # 684
# the value of cost function is [[0.35081343]] in iteration # 685
# the value of cost function is [[0.35058867]] in iteration # 686
# the value of cost function is [[0.35036429]] in iteration # 687
# the value of cost function is [[0.35014028]] in iteration # 688
# the value of cost function is [[0.34991664]] in iteration # 689
# the value of cost function is [[0.34969336]] in iteration # 690
# the value of cost function is [[0.34947046]] in iteration # 691
# the value of cost function is [[0.34924792]] in iteration # 692
# the value of cost function is [[0.34902575]] in iteration # 693
# the value of cost function is [[0.34880395]] in iteration # 694
# the value of cost function is [[0.34858251]] in iteration # 695
# the value of cost function is [[0.34836143]] in iteration # 696
# the value of cost function is [[0.34814072]] in iteration # 697
# the value of cost function is [[0.34792037]] in iteration # 698
# the value of cost function is [[0.34770038]] in iteration # 699
# the value of cost function is [[0.34748075]] in iteration # 700
# the value of cost function is [[0.34726148]] in iteration # 701
# the value of cost function is [[0.34704257]] in iteration # 702
# the value of cost function is [[0.34682401]] in iteration # 703
# the value of cost function is [[0.34660581]] in iteration # 704
# the value of cost function is [[0.34638797]] in iteration # 705
# the value of cost function is [[0.34617049]] in iteration # 706
# the value of cost function is [[0.34595336]] in iteration # 707
# the value of cost function is [[0.34573658]] in iteration # 708
# the value of cost function is [[0.34552016]] in iteration # 709
# the value of cost function is [[0.34530408]] in iteration # 710
# the value of cost function is [[0.34508836]] in iteration # 711
# the value of cost function is [[0.34487299]] in iteration # 712
# the value of cost function is [[0.34465797]] in iteration # 713
# the value of cost function is [[0.3444433]] in iteration # 714
# the value of cost function is [[0.34422897]] in iteration # 715
# the value of cost function is [[0.34401499]] in iteration # 716
# the value of cost function is [[0.34380136]] in iteration # 717
# the value of cost function is [[0.34358807]] in iteration # 718
# the value of cost function is [[0.34337513]] in iteration # 719
# the value of cost function is [[0.34316253]] in iteration # 720
# the value of cost function is [[0.34295028]] in iteration # 721
# the value of cost function is [[0.34273836]] in iteration # 722
# the value of cost function is [[0.34252679]] in iteration # 723
# the value of cost function is [[0.34231556]] in iteration # 724
# the value of cost function is [[0.34210467]] in iteration # 725
# the value of cost function is [[0.34189412]] in iteration # 726
# the value of cost function is [[0.3416839]] in iteration # 727
# the value of cost function is [[0.34147402]] in iteration # 728
# the value of cost function is [[0.34126448]] in iteration # 729
# the value of cost function is [[0.34105528]] in iteration # 730
# the value of cost function is [[0.34084641]] in iteration # 731
# the value of cost function is [[0.34063787]] in iteration # 732
# the value of cost function is [[0.34042967]] in iteration # 733
# the value of cost function is [[0.3402218]] in iteration # 734
# the value of cost function is [[0.34001427]] in iteration # 735
# the value of cost function is [[0.33980706]] in iteration # 736
# the value of cost function is [[0.33960019]] in iteration # 737
# the value of cost function is [[0.33939364]] in iteration # 738
# the value of cost function is [[0.33918742]] in iteration # 739
# the value of cost function is [[0.33898154]] in iteration # 740
# the value of cost function is [[0.33877597]] in iteration # 741
# the value of cost function is [[0.33857074]] in iteration # 742
# the value of cost function is [[0.33836583]] in iteration # 743
# the value of cost function is [[0.33816125]] in iteration # 744
# the value of cost function is [[0.33795699]] in iteration # 745
# the value of cost function is [[0.33775305]] in iteration # 746
# the value of cost function is [[0.33754944]] in iteration # 747
# the value of cost function is [[0.33734615]] in iteration # 748
# the value of cost function is [[0.33714318]] in iteration # 749
# the value of cost function is [[0.33694053]] in iteration # 750
# the value of cost function is [[0.33673821]] in iteration # 751
# ...
# the value of cost function is [[0.26396807]] in iteration # 1256
# the value of cost function is [[0.26386576]] in iteration # 1257
# the value of cost function is [[0.26376357]] in iteration # 1258
# the value of cost function is [[0.2636615]] in iteration # 1259
# the value of cost function is [[0.26355954]] in iteration # 1260
# the value of cost function is [[0.26345771]] in iteration # 1261
# the value of cost function is [[0.26335599]] in iteration # 1262
# the value of cost function is [[0.26325438]] in iteration # 1263
# the value of cost function is [[0.2631529]] in iteration # 1264
# the value of cost function is [[0.26305153]] in iteration # 1265
# the value of cost function is [[0.26295028]] in iteration # 1266
# the value of cost function is [[0.26284914]] in iteration # 1267
# the value of cost function is [[0.26274812]] in iteration # 1268
# the value of cost function is [[0.26264722]] in iteration # 1269
# the value of cost function is [[0.26254643]] in iteration # 1270
# the value of cost function is [[0.26244576]] in iteration # 1271
# the value of cost function is [[0.2623452]] in iteration # 1272
# the value of cost function is [[0.26224476]] in iteration # 1273
# the value of cost function is [[0.26214443]] in iteration # 1274
# the value of cost function is [[0.26204422]] in iteration # 1275
# the value of cost function is [[0.26194413]] in iteration # 1276
# the value of cost function is [[0.26184414]] in iteration # 1277
# the value of cost function is [[0.26174428]] in iteration # 1278
# the value of cost function is [[0.26164452]] in iteration # 1279
# the value of cost function is [[0.26154488]] in iteration # 1280
# the value of cost function is [[0.26144536]] in iteration # 1281
# the value of cost function is [[0.26134594]] in iteration # 1282
# the value of cost function is [[0.26124664]] in iteration # 1283
# the value of cost function is [[0.26114746]] in iteration # 1284
# the value of cost function is [[0.26104838]] in iteration # 1285
# the value of cost function is [[0.26094942]] in iteration # 1286
# the value of cost function is [[0.26085058]] in iteration # 1287
# the value of cost function is [[0.26075184]] in iteration # 1288
# the value of cost function is [[0.26065322]] in iteration # 1289
# the value of cost function is [[0.26055471]] in iteration # 1290
# the value of cost function is [[0.26045631]] in iteration # 1291
# the value of cost function is [[0.26035802]] in iteration # 1292
# the value of cost function is [[0.26025984]] in iteration # 1293
# the value of cost function is [[0.26016178]] in iteration # 1294
# the value of cost function is [[0.26006383]] in iteration # 1295
# the value of cost function is [[0.25996598]] in iteration # 1296
# the value of cost function is [[0.25986825]] in iteration # 1297
# the value of cost function is [[0.25977063]] in iteration # 1298
# the value of cost function is [[0.25967312]] in iteration # 1299
# the value of cost function is [[0.25957572]] in iteration # 1300
# the value of cost function is [[0.25947843]] in iteration # 1301
# the value of cost function is [[0.25938124]] in iteration # 1302
# the value of cost function is [[0.25928417]] in iteration # 1303
# the value of cost function is [[0.25918721]] in iteration # 1304
# the value of cost function is [[0.25909036]] in iteration # 1305
# the value of cost function is [[0.25899361]] in iteration # 1306
# the value of cost function is [[0.25889698]] in iteration # 1307
# the value of cost function is [[0.25880045]] in iteration # 1308
# the value of cost function is [[0.25870404]] in iteration # 1309
# the value of cost function is [[0.25860773]] in iteration # 1310
# the value of cost function is [[0.25851153]] in iteration # 1311
# the value of cost function is [[0.25841543]] in iteration # 1312
# the value of cost function is [[0.25831945]] in iteration # 1313
# the value of cost function is [[0.25822357]] in iteration # 1314
# the value of cost function is [[0.2581278]] in iteration # 1315
# the value of cost function is [[0.25803214]] in iteration # 1316
# the value of cost function is [[0.25793658]] in iteration # 1317
# the value of cost function is [[0.25784113]] in iteration # 1318
# the value of cost function is [[0.25774579]] in iteration # 1319
# the value of cost function is [[0.25765056]] in iteration # 1320
# the value of cost function is [[0.25755543]] in iteration # 1321
# the value of cost function is [[0.2574604]] in iteration # 1322
# the value of cost function is [[0.25736549]] in iteration # 1323
# the value of cost function is [[0.25727068]] in iteration # 1324
# the value of cost function is [[0.25717597]] in iteration # 1325
# the value of cost function is [[0.25708137]] in iteration # 1326
# the value of cost function is [[0.25698688]] in iteration # 1327
# the value of cost function is [[0.25689249]] in iteration # 1328
# the value of cost function is [[0.25679821]] in iteration # 1329
# the value of cost function is [[0.25670403]] in iteration # 1330
# the value of cost function is [[0.25660995]] in iteration # 1331
# the value of cost function is [[0.25651598]] in iteration # 1332
# the value of cost function is [[0.25642212]] in iteration # 1333
# the value of cost function is [[0.25632836]] in iteration # 1334
# the value of cost function is [[0.2562347]] in iteration # 1335
# the value of cost function is [[0.25614115]] in iteration # 1336
# the value of cost function is [[0.2560477]] in iteration # 1337
# the value of cost function is [[0.25595435]] in iteration # 1338
# the value of cost function is [[0.25586111]] in iteration # 1339
# the value of cost function is [[0.25576797]] in iteration # 1340
# the value of cost function is [[0.25567493]] in iteration # 1341
# the value of cost function is [[0.255582]] in iteration # 1342
# the value of cost function is [[0.25548917]] in iteration # 1343
# the value of cost function is [[0.25539644]] in iteration # 1344
# the value of cost function is [[0.25530381]] in iteration # 1345
# the value of cost function is [[0.25521129]] in iteration # 1346
# the value of cost function is [[0.25511887]] in iteration # 1347
# the value of cost function is [[0.25502654]] in iteration # 1348
# the value of cost function is [[0.25493433]] in iteration # 1349
# the value of cost function is [[0.25484221]] in iteration # 1350
# the value of cost function is [[0.25475019]] in iteration # 1351
# the value of cost function is [[0.25465828]] in iteration # 1352
# the value of cost function is [[0.25456646]] in iteration # 1353
# the value of cost function is [[0.25447475]] in iteration # 1354
# the value of cost function is [[0.25438314]] in iteration # 1355
# the value of cost function is [[0.25429163]] in iteration # 1356
# the value of cost function is [[0.25420022]] in iteration # 1357
# the value of cost function is [[0.25410891]] in iteration # 1358
# the value of cost function is [[0.25401769]] in iteration # 1359
# the value of cost function is [[0.25392658]] in iteration # 1360
# the value of cost function is [[0.25383557]] in iteration # 1361
# the value of cost function is [[0.25374466]] in iteration # 1362
# the value of cost function is [[0.25365385]] in iteration # 1363
# the value of cost function is [[0.25356313]] in iteration # 1364
# the value of cost function is [[0.25347252]] in iteration # 1365
# the value of cost function is [[0.25338201]] in iteration # 1366
# the value of cost function is [[0.25329159]] in iteration # 1367
# the value of cost function is [[0.25320127]] in iteration # 1368
# the value of cost function is [[0.25311105]] in iteration # 1369
# the value of cost function is [[0.25302093]] in iteration # 1370
# the value of cost function is [[0.25293091]] in iteration # 1371
# the value of cost function is [[0.25284098]] in iteration # 1372
# the value of cost function is [[0.25275115]] in iteration # 1373
# the value of cost function is [[0.25266142]] in iteration # 1374
# the value of cost function is [[0.25257179]] in iteration # 1375
# the value of cost function is [[0.25248226]] in iteration # 1376
# the value of cost function is [[0.25239282]] in iteration # 1377
# the value of cost function is [[0.25230348]] in iteration # 1378
# the value of cost function is [[0.25221424]] in iteration # 1379
# the value of cost function is [[0.25212509]] in iteration # 1380
# the value of cost function is [[0.25203604]] in iteration # 1381
# the value of cost function is [[0.25194708]] in iteration # 1382
# the value of cost function is [[0.25185823]] in iteration # 1383
# the value of cost function is [[0.25176946]] in iteration # 1384
# the value of cost function is [[0.2516808]] in iteration # 1385
# the value of cost function is [[0.25159223]] in iteration # 1386
# the value of cost function is [[0.25150375]] in iteration # 1387
# the value of cost function is [[0.25141538]] in iteration # 1388
# the value of cost function is [[0.25132709]] in iteration # 1389
# the value of cost function is [[0.2512389]] in iteration # 1390
# the value of cost function is [[0.25115081]] in iteration # 1391
# the value of cost function is [[0.25106281]] in iteration # 1392
# the value of cost function is [[0.25097491]] in iteration # 1393
# the value of cost function is [[0.2508871]] in iteration # 1394
# the value of cost function is [[0.25079939]] in iteration # 1395
# the value of cost function is [[0.25071176]] in iteration # 1396
# the value of cost function is [[0.25062424]] in iteration # 1397
# the value of cost function is [[0.25053681]] in iteration # 1398
# the value of cost function is [[0.25044947]] in iteration # 1399
# the value of cost function is [[0.25036222]] in iteration # 1400
# the value of cost function is [[0.25027507]] in iteration # 1401
# the value of cost function is [[0.25018801]] in iteration # 1402
# the value of cost function is [[0.25010105]] in iteration # 1403
# the value of cost function is [[0.25001418]] in iteration # 1404
# the value of cost function is [[0.2499274]] in iteration # 1405
# the value of cost function is [[0.24984071]] in iteration # 1406
# the value of cost function is [[0.24975412]] in iteration # 1407
# the value of cost function is [[0.24966762]] in iteration # 1408
# the value of cost function is [[0.24958121]] in iteration # 1409
# the value of cost function is [[0.2494949]] in iteration # 1410
# the value of cost function is [[0.24940867]] in iteration # 1411
# the value of cost function is [[0.24932254]] in iteration # 1412
# the value of cost function is [[0.2492365]] in iteration # 1413
# the value of cost function is [[0.24915055]] in iteration # 1414
# the value of cost function is [[0.2490647]] in iteration # 1415
# the value of cost function is [[0.24897893]] in iteration # 1416
# the value of cost function is [[0.24889326]] in iteration # 1417
# the value of cost function is [[0.24880767]] in iteration # 1418
# the value of cost function is [[0.24872218]] in iteration # 1419
# the value of cost function is [[0.24863678]] in iteration # 1420
# the value of cost function is [[0.24855147]] in iteration # 1421
# the value of cost function is [[0.24846625]] in iteration # 1422
# the value of cost function is [[0.24838112]] in iteration # 1423
# the value of cost function is [[0.24829608]] in iteration # 1424
# the value of cost function is [[0.24821113]] in iteration # 1425
# the value of cost function is [[0.24812627]] in iteration # 1426
# the value of cost function is [[0.2480415]] in iteration # 1427
# the value of cost function is [[0.24795682]] in iteration # 1428
# the value of cost function is [[0.24787223]] in iteration # 1429
# the value of cost function is [[0.24778773]] in iteration # 1430
# the value of cost function is [[0.24770331]] in iteration # 1431
# the value of cost function is [[0.24761899]] in iteration # 1432
# the value of cost function is [[0.24753476]] in iteration # 1433
# the value of cost function is [[0.24745061]] in iteration # 1434
# the value of cost function is [[0.24736656]] in iteration # 1435
# the value of cost function is [[0.24728259]] in iteration # 1436
# the value of cost function is [[0.24719871]] in iteration # 1437
# the value of cost function is [[0.24711492]] in iteration # 1438
# the value of cost function is [[0.24703121]] in iteration # 1439
# the value of cost function is [[0.2469476]] in iteration # 1440
# the value of cost function is [[0.24686407]] in iteration # 1441
# the value of cost function is [[0.24678063]] in iteration # 1442
# the value of cost function is [[0.24669728]] in iteration # 1443
# the value of cost function is [[0.24661401]] in iteration # 1444
# the value of cost function is [[0.24653084]] in iteration # 1445
# the value of cost function is [[0.24644775]] in iteration # 1446
# the value of cost function is [[0.24636474]] in iteration # 1447
# the value of cost function is [[0.24628183]] in iteration # 1448
# the value of cost function is [[0.246199]] in iteration # 1449
# the value of cost function is [[0.24611626]] in iteration # 1450
# the value of cost function is [[0.2460336]] in iteration # 1451
# the value of cost function is [[0.24595103]] in iteration # 1452
# the value of cost function is [[0.24586855]] in iteration # 1453
# the value of cost function is [[0.24578615]] in iteration # 1454
# the value of cost function is [[0.24570384]] in iteration # 1455
# the value of cost function is [[0.24562161]] in iteration # 1456
# the value of cost function is [[0.24553947]] in iteration # 1457
# the value of cost function is [[0.24545742]] in iteration # 1458
# the value of cost function is [[0.24537545]] in iteration # 1459
# the value of cost function is [[0.24529357]] in iteration # 1460
# the value of cost function is [[0.24521177]] in iteration # 1461
# the value of cost function is [[0.24513005]] in iteration # 1462
# the value of cost function is [[0.24504843]] in iteration # 1463
# the value of cost function is [[0.24496688]] in iteration # 1464
# the value of cost function is [[0.24488542]] in iteration # 1465
# the value of cost function is [[0.24480405]] in iteration # 1466
# the value of cost function is [[0.24472276]] in iteration # 1467
# the value of cost function is [[0.24464155]] in iteration # 1468
# the value of cost function is [[0.24456043]] in iteration # 1469
# the value of cost function is [[0.24447939]] in iteration # 1470
# the value of cost function is [[0.24439844]] in iteration # 1471
# the value of cost function is [[0.24431757]] in iteration # 1472
# the value of cost function is [[0.24423678]] in iteration # 1473
# the value of cost function is [[0.24415608]] in iteration # 1474
# the value of cost function is [[0.24407546]] in iteration # 1475
# the value of cost function is [[0.24399493]] in iteration # 1476
# the value of cost function is [[0.24391447]] in iteration # 1477
# the value of cost function is [[0.2438341]] in iteration # 1478
# the value of cost function is [[0.24375382]] in iteration # 1479
# the value of cost function is [[0.24367361]] in iteration # 1480
# the value of cost function is [[0.24359349]] in iteration # 1481
# the value of cost function is [[0.24351345]] in iteration # 1482
# the value of cost function is [[0.2434335]] in iteration # 1483
# the value of cost function is [[0.24335362]] in iteration # 1484
# the value of cost function is [[0.24327383]] in iteration # 1485
# the value of cost function is [[0.24319412]] in iteration # 1486
# the value of cost function is [[0.24311449]] in iteration # 1487
# the value of cost function is [[0.24303494]] in iteration # 1488
# the value of cost function is [[0.24295548]] in iteration # 1489
# the value of cost function is [[0.24287609]] in iteration # 1490
# the value of cost function is [[0.24279679]] in iteration # 1491
# the value of cost function is [[0.24271757]] in iteration # 1492
# the value of cost function is [[0.24263843]] in iteration # 1493
# the value of cost function is [[0.24255937]] in iteration # 1494
# the value of cost function is [[0.24248039]] in iteration # 1495
# the value of cost function is [[0.2424015]] in iteration # 1496
# the value of cost function is [[0.24232268]] in iteration # 1497
# the value of cost function is [[0.24224394]] in iteration # 1498
# the value of cost function is [[0.24216529]] in iteration # 1499
# The cost after training is 0.24216529.
# The resulting vector of weights is [7e-08, 0.0005239, -0.00055517]

# %% [markdown]
# **Expected Output**:
#
# ```
# The cost after training is 0.24216529.
# The resulting vector of weights is [7e-08, 0.0005239, -0.00055517]
# ```

# %% [markdown]
# # Part 4: Test your logistic regression
#
# It is time for you to test your logistic regression function on some new input that your model has not seen before.
#
# #### Instructions: Write `predict_tweet`
# Predict whether a tweet is positive or negative.
#
# * Given a tweet, process it, then extract the features.
# * Apply the model's learned weights on the features to get the logits.
# * Apply the sigmoid to the logits to get the prediction (a value between 0 and 1).
#
# $$y_{pred} = sigmoid(\mathbf{x} \cdot \theta)$$

# %%
# UNQ_C4 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def predict_tweet(tweet, freqs, theta):
    '''
    Input: 
        tweet: a string
        freqs: a dictionary corresponding to the frequencies of each tuple (word, label)
        theta: (3,1) vector of weights
    Output: 
        y_pred: the probability of a tweet being positive or negative
    '''
    ### START CODE HERE (REPLACE INSTANCES OF 'None' with your code) ###
    
    # extract the features of the tweet and store it into x
    # featues are [bias, positivewordcount, negativewordcount]
    x = extract_features(tweet, freqs)
    
    # make the prediction using x and theta
    y_pred = np.array(sigmoid(np.dot(x,theta))) #sigmoid(np.dot(x,theta))
    
    ### END CODE HERE ###
    
    return y_pred

# %%
# Run this cell to test your function
for tweet in ['I am happy', 'I am bad', 'this movie should have been great.', 'great', 'great great', 'great great great', 'great great great great']:
    print( '%s -> %f' % (tweet, predict_tweet(tweet, freqs, theta)))
# Out:
# I am happy -> 0.518580
# I am bad -> 0.494339
# this movie should have been great. -> 0.515331
# great -> 0.515464
# great great -> 0.530898
# great great great -> 0.546273
# great great great great -> 0.561561

# %% [markdown]
# **Expected Output**:
# ```
# I am happy -> 0.518580
# I am bad -> 0.494339
# this movie should have been great. -> 0.515331
# great -> 0.515464
# great great -> 0.530898
# great great great -> 0.546273
# great great great great -> 0.561561
# ```

# %%
# Feel free to check the sentiment of your own tweet below
my_tweet = 'I am learning but it is tough but i am stronger & happier & greateful'
predict_tweet(my_tweet, freqs, theta)
# Out:
# array([0.51580947])

# %% [markdown]
# ## Check performance using the test set
# After training your model using the training set above, check how your model might perform on real, unseen data, by testing it against the test set.
#
# #### Instructions: Implement `test_logistic_regression`
# * Given the test data and the weights of your trained model, calculate the accuracy of your logistic regression model.
# * Use your `predict_tweet()` function to make predictions on each tweet in the test set.
# * If the prediction is > 0.5, set the model's classification `y_hat` to 1, otherwise set the model's classification `y_hat` to 0.
# * A prediction is accurate when `y_hat` equals `test_y`.  Sum up all the instances when they are equal and divide by `m`.

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li>Use np.asarray() to convert a list to a numpy array</li>
#     <li>Use np.squeeze() to make an (m,1) dimensional array into an (m,) array </li>
# </ul>
# </p>

# %%
# UNQ_C5 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def test_logistic_regression(test_x, test_y, freqs, theta):
    """
    Input: 
        test_x: a list of tweets
        test_y: (m, 1) vector with the corresponding labels for the list of tweets
        freqs: a dictionary with the frequency of each pair (or tuple)
        theta: weight vector of dimension (3, 1)
    Output: 
        accuracy: (# of tweets classified correctly) / (total # of tweets)
    """
    
    ### START CODE HERE (REPLACE INSTANCES OF 'None' with your code) ###
    
    # the list for storing predictions
    y_hat = []
    
    for tweet in test_x:
        # get the label prediction for the tweet
        y_pred = predict_tweet(tweet, freqs, theta)
        
        if y_pred > 0.5:
            # append 1.0 to the list
            y_hat.append(1)
        else:
            # append 0 to the list
            y_hat.append(0)

    # With the above implementation, y_hat is a list, but test_y is (m,1) array
    # convert both to one-dimensional arrays in order to compare them using the '==' operator
    accuracy = np.sum((np.array(y_hat) == np.squeeze(test_y)))/len(test_y)

    ### END CODE HERE ###
    
    return accuracy

# %%
tmp_accuracy = test_logistic_regression(test_x, test_y, freqs, theta)
print(f"Logistic regression model's accuracy = {tmp_accuracy:.4f}")
# Out:
# Logistic regression model's accuracy = 0.9950

# %% [markdown]
# #### Expected Output:
# ```0.9950```
# Pretty good!

# %% [markdown]
# # Part 5: Error Analysis
#
# In this part you will see some tweets that your model misclassified. Why do you think the misclassifications happened? Specifically what kind of tweets does your model misclassify?

# %%
# Some error analysis done for you
print('Label Predicted Tweet')
for x,y in zip(test_x,test_y):
    y_hat = predict_tweet(x, freqs, theta)

    if np.abs(y - (y_hat > 0.5)) > 0:
        print('THE TWEET IS:', x)
        print('THE PROCESSED TWEET IS:', process_tweet(x))
        print('%d\t%0.8f\t%s' % (y, y_hat, ' '.join(process_tweet(x)).encode('ascii', 'ignore')))
# Out:
# Label Predicted Tweet
# THE TWEET IS: @jaredNOTsubway @iluvmariah @Bravotv Then that truly is a LATERAL move! Now, we all know the Queen Bee is UPWARD BOUND : ) #MovingOnUp
# THE PROCESSED TWEET IS: ['truli', 'later', 'move', 'know', 'queen', 'bee', 'upward', 'bound', 'movingonup']
# 1	0.49996890	b'truli later move know queen bee upward bound movingonup'
# THE TWEET IS: @MarkBreech Not sure it would be good thing 4 my bottom daring 2 say 2 Miss B but Im gonna be so stubborn on mouth soaping ! #NotHavingit :p
# THE PROCESSED TWEET IS: ['sure', 'would', 'good', 'thing', '4', 'bottom', 'dare', '2', 'say', '2', 'miss', 'b', 'im', 'gonna', 'stubborn', 'mouth', 'soap', 'nothavingit', ':p']
# 1	0.48622857	b'sure would good thing 4 bottom dare 2 say 2 miss b im gonna stubborn mouth soap nothavingit :p'
# THE TWEET IS: I'm playing Brain Dots : ) #BrainDots
# http://t.co/UGQzOx0huu
# THE PROCESSED TWEET IS: ["i'm", 'play', 'brain', 'dot', 'braindot']
# 1	0.48370665	b"i'm play brain dot braindot"
# THE TWEET IS: I'm playing Brain Dots : ) #BrainDots http://t.co/aOKldo3GMj http://t.co/xWCM9qyRG5
# THE PROCESSED TWEET IS: ["i'm", 'play', 'brain', 'dot', 'braindot']
# 1	0.48370665	b"i'm play brain dot braindot"
# THE TWEET IS: I'm playing Brain Dots : ) #BrainDots http://t.co/R2JBO8iNww http://t.co/ow5BBwdEMY
# THE PROCESSED TWEET IS: ["i'm", 'play', 'brain', 'dot', 'braindot']
# 1	0.48370665	b"i'm play brain dot braindot"
# THE TWEET IS: off to the park to get some sunlight : )
# THE PROCESSED TWEET IS: ['park', 'get', 'sunlight']
# 1	0.49578765	b'park get sunlight'
# THE TWEET IS: @msarosh Uff Itna Miss karhy thy ap :p
# THE PROCESSED TWEET IS: ['uff', 'itna', 'miss', 'karhi', 'thi', 'ap', ':p']
# 1	0.48199810	b'uff itna miss karhi thi ap :p'
# THE TWEET IS: @phenomyoutube u probs had more fun with david than me : (
# THE PROCESSED TWEET IS: ['u', 'prob', 'fun', 'david']
# 0	0.50020353	b'u prob fun david'
# THE TWEET IS: pats jay : (
# THE PROCESSED TWEET IS: ['pat', 'jay']
# 0	0.50039294	b'pat jay'
# THE TWEET IS: my beloved grandmother : ( https://t.co/wt4oXq5xCf
# THE PROCESSED TWEET IS: ['belov', 'grandmoth']
# 0	0.50000002	b'belov grandmoth'

# %% [markdown]
# Later in this specialization, we will see how we can use deep learning to improve the prediction performance.

# %% [markdown]
# # Part 6: Predict with your own tweet

# %%
# Feel free to change the tweet below
my_tweet = 'This is a ridiculously bright movie. The plot was terrible and I was sad until the ending!'
print(process_tweet(my_tweet))
y_hat = predict_tweet(my_tweet, freqs, theta)
print(y_hat)
if y_hat > 0.5:
    print('Positive sentiment')
else: 
    print('Negative sentiment')
# Out:
# ['ridicul', 'bright', 'movi', 'plot', 'terribl', 'sad', 'end']
# [0.48139087]
# Negative sentiment
